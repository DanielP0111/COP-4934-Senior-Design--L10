# %% [markdown]
# # Run System
#
# This notebook contains all of the necessary commands to start up the Docker network and run the WebUI
#
# ## Start Containers and Pull Ollama Model
#
# Run this cell to start up all of the containers in the network and pull the qwen2.5:14b model to the Ollama container.
#
# If this is your first time running the system, it may take 5-10 minutes to pull each of the Docker images and the Qwen model.
#
# Subsequent startups should only take a few seconds.

# %%
# !docker compose up -d --build
# !docker exec -it ollama ollama pull qwen2.5:14b
# Out:
# [+] Building 0.0s (0/1)
#  => [internal] load local bake definitions                                 0.0s
# [+] Building 0.2s (1/1)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 1.64kB                                           0.0s
# [+] Building 0.3s (1/1)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 1.64kB                                           0.0s
# [+] Building 0.3s (1/2)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 1.64kB                                           0.0s
# [+] Building 0.5s (1/4)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 1.64kB                                           0.0s
#  => [mysql internal] load build definition from Dockerfile.database        0.1s
#  => => transferring dockerfile:                                            0.0s
#  => [agents internal] load build definition from Dockerfile.agents         0.1s
#  => [kali internal] load build definition from Dockerfile.kali             0.1s
# [+] Building 0.6s (1/4)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 1.64kB                                           0.0s
#  => [mysql internal] load build definition from Dockerfile.database        0.2s
#  => => transferring dockerfile: 245B                                       0.0s
#  => [agents internal] load build definition from Dockerfile.agents         0.2s
#  => => transferring dockerfile:                                            0.0s
#  => [kali internal] load build definition from Dockerfile.kali             0.2s
#  => => transferring dockerfile: 314B                                       0.0s
# [+] Building 0.7s (2/4)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 1.64kB                                           0.0s
#  => [mysql internal] load build definition from Dockerfile.database        0.3s
#  => => transferring dockerfile: 245B                                       0.0s
#  => [agents internal] load build definition from Dockerfile.agents         0.3s
#  => => transferring dockerfile: 218B                                       0.0s
#  => [kali internal] load build definition from Dockerfile.kali             0.4s
#  => => transferring dockerfile: 314B                                       0.0s
# [+] Building 0.8s (3/4)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 1.64kB                                           0.0s
#  => [mysql internal] load build definition from Dockerfile.database        0.3s
#  => => transferring dockerfile: 245B                                       0.0s
#  => [agents internal] load build definition from Dockerfile.agents         0.4s
#  => => transferring dockerfile: 218B                                       0.0s
#  => [kali internal] load build definition from Dockerfile.kali             0.4s
#  => => transferring dockerfile: 314B                                       0.0s
# [+] Building 1.0s (4/5)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 1.64kB                                           0.0s
#  => [mysql internal] load build definition from Dockerfile.database        0.3s
#  => => transferring dockerfile: 245B                                       0.0s
#  => [agents internal] load build definition from Dockerfile.agents         0.6s
#  => => transferring dockerfile: 218B                                       0.0s
#  => [kali internal] load build definition from Dockerfile.kali             0.4s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [mysql internal] load metadata for docker.io/library/mysql:latest      0.1s
# [+] Building 1.1s (4/7)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 1.64kB                                           0.0s
#  => [mysql internal] load build definition from Dockerfile.database        0.3s
#  => => transferring dockerfile: 245B                                       0.0s
#  => [agents internal] load build definition from Dockerfile.agents         0.6s
#  => => transferring dockerfile: 218B                                       0.0s
#  => [kali internal] load build definition from Dockerfile.kali             0.4s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [mysql internal] load metadata for docker.io/library/mysql:latest      0.3s
#  => [kali internal] load metadata for docker.io/kalilinux/kali-rolling:la  0.1s
#  => [agents internal] load metadata for docker.io/library/python:3.12-alp  0.0s
# [+] Building 1.3s (4/7)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 1.64kB                                           0.0s
#  => [mysql internal] load build definition from Dockerfile.database        0.3s
#  => => transferring dockerfile: 245B                                       0.0s
#  => [agents internal] load build definition from Dockerfile.agents         0.6s
#  => => transferring dockerfile: 218B                                       0.0s
#  => [kali internal] load build definition from Dockerfile.kali             0.4s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [mysql internal] load metadata for docker.io/library/mysql:latest      0.4s
#  => [kali internal] load metadata for docker.io/kalilinux/kali-rolling:la  0.3s
#  => [agents internal] load metadata for docker.io/library/python:3.12-alp  0.2s
# [+] Building 1.4s (4/7)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 1.64kB                                           0.0s
#  => [mysql internal] load build definition from Dockerfile.database        0.3s
#  => => transferring dockerfile: 245B                                       0.0s
#  => [agents internal] load build definition from Dockerfile.agents         0.6s
#  => => transferring dockerfile: 218B                                       0.0s
#  => [kali internal] load build definition from Dockerfile.kali             0.4s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [mysql internal] load metadata for docker.io/library/mysql:latest      0.6s
#  => [kali internal] load metadata for docker.io/kalilinux/kali-rolling:la  0.4s
#  => [agents internal] load metadata for docker.io/library/python:3.12-alp  0.3s
# [+] Building 1.6s (4/7)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 1.64kB                                           0.0s
#  => [mysql internal] load build definition from Dockerfile.database        0.3s
#  => => transferring dockerfile: 245B                                       0.0s
#  => [agents internal] load build definition from Dockerfile.agents         0.6s
#  => => transferring dockerfile: 218B                                       0.0s
#  => [kali internal] load build definition from Dockerfile.kali             0.4s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [mysql internal] load metadata for docker.io/library/mysql:latest      0.7s
#  => [kali internal] load metadata for docker.io/kalilinux/kali-rolling:la  0.6s
#  => [agents internal] load metadata for docker.io/library/python:3.12-alp  0.5s
# [+] Building 1.7s (4/7)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 1.64kB                                           0.0s
#  => [mysql internal] load build definition from Dockerfile.database        0.3s
#  => => transferring dockerfile: 245B                                       0.0s
#  => [agents internal] load build definition from Dockerfile.agents         0.6s
#  => => transferring dockerfile: 218B                                       0.0s
#  => [kali internal] load build definition from Dockerfile.kali             0.4s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [mysql internal] load metadata for docker.io/library/mysql:latest      0.9s
#  => [kali internal] load metadata for docker.io/kalilinux/kali-rolling:la  0.7s
#  => [agents internal] load metadata for docker.io/library/python:3.12-alp  0.6s
# [+] Building 1.9s (4/7)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 1.64kB                                           0.0s
#  => [mysql internal] load build definition from Dockerfile.database        0.3s
#  => => transferring dockerfile: 245B                                       0.0s
#  => [agents internal] load build definition from Dockerfile.agents         0.6s
#  => => transferring dockerfile: 218B                                       0.0s
#  => [kali internal] load build definition from Dockerfile.kali             0.4s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [mysql internal] load metadata for docker.io/library/mysql:latest      1.0s
#  => [kali internal] load metadata for docker.io/kalilinux/kali-rolling:la  0.9s
#  => [agents internal] load metadata for docker.io/library/python:3.12-alp  0.8s
# [+] Building 2.0s (4/7)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 1.64kB                                           0.0s
#  => [mysql internal] load build definition from Dockerfile.database        0.3s
#  => => transferring dockerfile: 245B                                       0.0s
#  => [agents internal] load build definition from Dockerfile.agents         0.6s
#  => => transferring dockerfile: 218B                                       0.0s
#  => [kali internal] load build definition from Dockerfile.kali             0.4s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [mysql internal] load metadata for docker.io/library/mysql:latest      1.2s
#  => [kali internal] load metadata for docker.io/kalilinux/kali-rolling:la  1.0s
#  => [agents internal] load metadata for docker.io/library/python:3.12-alp  0.9s
# [+] Building 2.2s (4/7)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 1.64kB                                           0.0s
#  => [mysql internal] load build definition from Dockerfile.database        0.3s
#  => => transferring dockerfile: 245B                                       0.0s
#  => [agents internal] load build definition from Dockerfile.agents         0.6s
#  => => transferring dockerfile: 218B                                       0.0s
#  => [kali internal] load build definition from Dockerfile.kali             0.4s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [mysql internal] load metadata for docker.io/library/mysql:latest      1.3s
#  => [kali internal] load metadata for docker.io/kalilinux/kali-rolling:la  1.2s
#  => [agents internal] load metadata for docker.io/library/python:3.12-alp  1.1s
# [+] Building 2.2s (5/7)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 1.64kB                                           0.0s
#  => [mysql internal] load build definition from Dockerfile.database        0.3s
#  => => transferring dockerfile: 245B                                       0.0s
#  => [agents internal] load build definition from Dockerfile.agents         0.6s
#  => => transferring dockerfile: 218B                                       0.0s
#  => [kali internal] load build definition from Dockerfile.kali             0.4s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [mysql internal] load metadata for docker.io/library/mysql:latest      1.4s
#  => [kali internal] load metadata for docker.io/kalilinux/kali-rolling:la  1.2s
#  => [agents internal] load metadata for docker.io/library/python:3.12-alp  1.1s
# [+] Building 2.4s (5/8)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 1.64kB                                           0.0s
#  => [mysql internal] load build definition from Dockerfile.database        0.3s
#  => => transferring dockerfile: 245B                                       0.0s
#  => [agents internal] load build definition from Dockerfile.agents         0.6s
#  => => transferring dockerfile: 218B                                       0.0s
#  => [kali internal] load build definition from Dockerfile.kali             0.4s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [mysql internal] load metadata for docker.io/library/mysql:latest      1.4s
#  => [kali internal] load metadata for docker.io/kalilinux/kali-rolling:la  1.4s
#  => [agents internal] load metadata for docker.io/library/python:3.12-alp  1.3s
#  => [mysql internal] load .dockerignore                                    0.2s
# [+] Building 2.4s (5/8)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 1.64kB                                           0.0s
#  => [mysql internal] load build definition from Dockerfile.database        0.3s
#  => => transferring dockerfile: 245B                                       0.0s
#  => [agents internal] load build definition from Dockerfile.agents         0.6s
#  => => transferring dockerfile: 218B                                       0.0s
#  => [kali internal] load build definition from Dockerfile.kali             0.4s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [mysql internal] load metadata for docker.io/library/mysql:latest      1.4s
#  => [kali internal] load metadata for docker.io/kalilinux/kali-rolling:la  1.4s
#  => [agents internal] load metadata for docker.io/library/python:3.12-alp  1.3s
#  => [mysql internal] load .dockerignore                                    0.2s
#  => => transferring context:                                               0.0s
# [+] Building 2.5s (6/9)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 1.64kB                                           0.0s
#  => [mysql internal] load build definition from Dockerfile.database        0.3s
#  => => transferring dockerfile: 245B                                       0.0s
#  => [agents internal] load build definition from Dockerfile.agents         0.6s
#  => => transferring dockerfile: 218B                                       0.0s
#  => [kali internal] load build definition from Dockerfile.kali             0.4s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [mysql internal] load metadata for docker.io/library/mysql:latest      1.4s
#  => [kali internal] load metadata for docker.io/kalilinux/kali-rolling:la  1.4s
#  => [agents internal] load metadata for docker.io/library/python:3.12-alp  1.4s
#  => [mysql internal] load .dockerignore                                    0.3s
#  => => transferring context: 2B                                            0.0s
#  => [kali internal] load .dockerignore                                     0.1s
#  => => transferring context:                                               0.0s
# [+] Building 2.6s (8/9)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 1.64kB                                           0.0s
#  => [mysql internal] load build definition from Dockerfile.database        0.3s
#  => => transferring dockerfile: 245B                                       0.0s
#  => [agents internal] load build definition from Dockerfile.agents         0.6s
#  => => transferring dockerfile: 218B                                       0.0s
#  => [kali internal] load build definition from Dockerfile.kali             0.4s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [mysql internal] load metadata for docker.io/library/mysql:latest      1.4s
#  => [kali internal] load metadata for docker.io/kalilinux/kali-rolling:la  1.4s
#  => [agents internal] load metadata for docker.io/library/python:3.12-alp  1.4s
#  => [mysql internal] load .dockerignore                                    0.4s
#  => => transferring context: 2B                                            0.0s
#  => [agents internal] load .dockerignore                                   0.2s
#  => => transferring context: 2B                                            0.0s
# [+] Building 2.7s (8/12)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 1.64kB                                           0.0s
#  => [mysql internal] load build definition from Dockerfile.database        0.3s
#  => => transferring dockerfile: 245B                                       0.0s
#  => [agents internal] load build definition from Dockerfile.agents         0.6s
#  => => transferring dockerfile: 218B                                       0.0s
#  => [kali internal] load build definition from Dockerfile.kali             0.4s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [mysql internal] load metadata for docker.io/library/mysql:latest      1.4s
#  => [kali internal] load metadata for docker.io/kalilinux/kali-rolling:la  1.4s
#  => [agents internal] load metadata for docker.io/library/python:3.12-alp  1.4s
#  => [mysql internal] load .dockerignore                                    0.4s
#  => => transferring context: 2B                                            0.0s
#  => [agents internal] load .dockerignore                                   0.4s
#  => => transferring context: 2B                                            0.0s
#  => [mysql internal] load build context                                    0.0s
#  => [mysql 1/2] FROM docker.io/library/mysql:latest@sha256:db32c8ec843c04  0.0s
# [+] Building 2.9s (10/20)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 1.64kB                                           0.0s
#  => [mysql internal] load build definition from Dockerfile.database        0.3s
#  => => transferring dockerfile: 245B                                       0.0s
#  => [agents internal] load build definition from Dockerfile.agents         0.6s
#  => => transferring dockerfile: 218B                                       0.0s
#  => [kali internal] load build definition from Dockerfile.kali             0.4s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [mysql internal] load metadata for docker.io/library/mysql:latest      1.4s
#  => [kali internal] load metadata for docker.io/kalilinux/kali-rolling:la  1.4s
#  => [agents internal] load metadata for docker.io/library/python:3.12-alp  1.4s
#  => [mysql internal] load .dockerignore                                    0.4s
#  => => transferring context: 2B                                            0.0s
#  => [agents internal] load .dockerignore                                   0.4s
#  => => transferring context: 2B                                            0.0s
#  => [mysql internal] load build context                                    0.1s
#  => => transferring context:                                               0.0s
#  => [mysql 1/2] FROM docker.io/library/mysql:latest@sha256:db32c8ec843c04  0.2s
#  => => resolve docker.io/library/mysql:latest@sha256:db32c8ec843c042a728e  0.1s
#  => [kali 1/3] FROM docker.io/kalilinux/kali-rolling:latest@sha256:05ac8a  0.1s
#  => [agents 1/4] FROM docker.io/library/python:3.12-alpine@sha256:2d91681  0.1s
#  => [agents internal] load build context                                   0.0s
# [+] Building 3.0s (11/20)
#  => [mysql internal] load build definition from Dockerfile.database        0.3s
#  => => transferring dockerfile: 245B                                       0.0s
#  => [agents internal] load build definition from Dockerfile.agents         0.6s
#  => => transferring dockerfile: 218B                                       0.0s
#  => [kali internal] load build definition from Dockerfile.kali             0.4s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [mysql internal] load metadata for docker.io/library/mysql:latest      1.4s
#  => [kali internal] load metadata for docker.io/kalilinux/kali-rolling:la  1.4s
#  => [agents internal] load metadata for docker.io/library/python:3.12-alp  1.4s
#  => [mysql internal] load .dockerignore                                    0.4s
#  => => transferring context: 2B                                            0.0s
#  => [agents internal] load .dockerignore                                   0.4s
#  => => transferring context: 2B                                            0.0s
#  => [mysql internal] load build context                                    0.3s
#  => => transferring context: 39B                                           0.0s
#  => [mysql 1/2] FROM docker.io/library/mysql:latest@sha256:db32c8ec843c04  0.3s
#  => => resolve docker.io/library/mysql:latest@sha256:db32c8ec843c042a728e  0.2s
#  => [kali 1/3] FROM docker.io/kalilinux/kali-rolling:latest@sha256:05ac8a  0.2s
#  => => resolve docker.io/kalilinux/kali-rolling:latest@sha256:05ac8ac0620  0.1s
#  => [agents 1/4] FROM docker.io/library/python:3.12-alpine@sha256:2d91681  0.2s
#  => => resolve docker.io/library/python:3.12-alpine@sha256:2d91681153dd4b  0.1s
#  => [agents internal] load build context                                   0.0s
# [+] Building 3.2s (11/20)
#  => [mysql internal] load build definition from Dockerfile.database        0.3s
#  => => transferring dockerfile: 245B                                       0.0s
#  => [agents internal] load build definition from Dockerfile.agents         0.6s
#  => => transferring dockerfile: 218B                                       0.0s
#  => [kali internal] load build definition from Dockerfile.kali             0.4s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [mysql internal] load metadata for docker.io/library/mysql:latest      1.4s
#  => [kali internal] load metadata for docker.io/kalilinux/kali-rolling:la  1.4s
#  => [agents internal] load metadata for docker.io/library/python:3.12-alp  1.4s
#  => [mysql internal] load .dockerignore                                    0.4s
#  => => transferring context: 2B                                            0.0s
#  => [agents internal] load .dockerignore                                   0.4s
#  => => transferring context: 2B                                            0.0s
#  => [mysql internal] load build context                                    0.3s
#  => => transferring context: 39B                                           0.0s
#  => [mysql 1/2] FROM docker.io/library/mysql:latest@sha256:db32c8ec843c04  0.5s
#  => => resolve docker.io/library/mysql:latest@sha256:db32c8ec843c042a728e  0.4s
#  => [kali 1/3] FROM docker.io/kalilinux/kali-rolling:latest@sha256:05ac8a  0.4s
#  => => resolve docker.io/kalilinux/kali-rolling:latest@sha256:05ac8ac0620  0.3s
#  => [agents 1/4] FROM docker.io/library/python:3.12-alpine@sha256:2d91681  0.4s
#  => => resolve docker.io/library/python:3.12-alpine@sha256:2d91681153dd4b  0.3s
#  => [agents internal] load build context                                   0.0s
# [+] Building 3.3s (11/20)
#  => [mysql internal] load build definition from Dockerfile.database        0.3s
#  => => transferring dockerfile: 245B                                       0.0s
#  => [agents internal] load build definition from Dockerfile.agents         0.6s
#  => => transferring dockerfile: 218B                                       0.0s
#  => [kali internal] load build definition from Dockerfile.kali             0.4s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [mysql internal] load metadata for docker.io/library/mysql:latest      1.4s
#  => [kali internal] load metadata for docker.io/kalilinux/kali-rolling:la  1.4s
#  => [agents internal] load metadata for docker.io/library/python:3.12-alp  1.4s
#  => [mysql internal] load .dockerignore                                    0.4s
#  => => transferring context: 2B                                            0.0s
#  => [agents internal] load .dockerignore                                   0.4s
#  => => transferring context: 2B                                            0.0s
#  => [mysql internal] load build context                                    0.3s
#  => => transferring context: 39B                                           0.0s
#  => [mysql 1/2] FROM docker.io/library/mysql:latest@sha256:db32c8ec843c04  0.6s
#  => => resolve docker.io/library/mysql:latest@sha256:db32c8ec843c042a728e  0.5s
#  => [kali 1/3] FROM docker.io/kalilinux/kali-rolling:latest@sha256:05ac8a  0.5s
#  => => resolve docker.io/kalilinux/kali-rolling:latest@sha256:05ac8ac0620  0.4s
#  => [agents 1/4] FROM docker.io/library/python:3.12-alpine@sha256:2d91681  0.5s
#  => => resolve docker.io/library/python:3.12-alpine@sha256:2d91681153dd4b  0.4s
#  => [agents internal] load build context                                   0.0s
# [+] Building 3.5s (11/20)
#  => [mysql internal] load build definition from Dockerfile.database        0.3s
#  => => transferring dockerfile: 245B                                       0.0s
#  => [agents internal] load build definition from Dockerfile.agents         0.6s
#  => => transferring dockerfile: 218B                                       0.0s
#  => [kali internal] load build definition from Dockerfile.kali             0.4s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [mysql internal] load metadata for docker.io/library/mysql:latest      1.4s
#  => [kali internal] load metadata for docker.io/kalilinux/kali-rolling:la  1.4s
#  => [agents internal] load metadata for docker.io/library/python:3.12-alp  1.4s
#  => [mysql internal] load .dockerignore                                    0.4s
#  => => transferring context: 2B                                            0.0s
#  => [agents internal] load .dockerignore                                   0.4s
#  => => transferring context: 2B                                            0.0s
#  => [mysql internal] load build context                                    0.3s
#  => => transferring context: 39B                                           0.0s
#  => [mysql 1/2] FROM docker.io/library/mysql:latest@sha256:db32c8ec843c04  0.8s
#  => => resolve docker.io/library/mysql:latest@sha256:db32c8ec843c042a728e  0.7s
#  => [kali 1/3] FROM docker.io/kalilinux/kali-rolling:latest@sha256:05ac8a  0.7s
#  => => resolve docker.io/kalilinux/kali-rolling:latest@sha256:05ac8ac0620  0.6s
#  => [agents 1/4] FROM docker.io/library/python:3.12-alpine@sha256:2d91681  0.7s
#  => => resolve docker.io/library/python:3.12-alpine@sha256:2d91681153dd4b  0.6s
#  => [agents internal] load build context                                   0.0s
# [+] Building 3.5s (11/20)
#  => [mysql internal] load build definition from Dockerfile.database        0.3s
#  => => transferring dockerfile: 245B                                       0.0s
#  => [agents internal] load build definition from Dockerfile.agents         0.6s
#  => => transferring dockerfile: 218B                                       0.0s
#  => [kali internal] load build definition from Dockerfile.kali             0.4s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [mysql internal] load metadata for docker.io/library/mysql:latest      1.4s
#  => [kali internal] load metadata for docker.io/kalilinux/kali-rolling:la  1.4s
#  => [agents internal] load metadata for docker.io/library/python:3.12-alp  1.4s
#  => [mysql internal] load .dockerignore                                    0.4s
#  => => transferring context: 2B                                            0.0s
#  => [agents internal] load .dockerignore                                   0.4s
#  => => transferring context: 2B                                            0.0s
#  => [mysql internal] load build context                                    0.3s
#  => => transferring context: 39B                                           0.0s
#  => [mysql 1/2] FROM docker.io/library/mysql:latest@sha256:db32c8ec843c04  0.8s
#  => => resolve docker.io/library/mysql:latest@sha256:db32c8ec843c042a728e  0.8s
#  => [kali 1/3] FROM docker.io/kalilinux/kali-rolling:latest@sha256:05ac8a  0.8s
#  => => resolve docker.io/kalilinux/kali-rolling:latest@sha256:05ac8ac0620  0.7s
#  => [agents 1/4] FROM docker.io/library/python:3.12-alpine@sha256:2d91681  0.7s
#  => => resolve docker.io/library/python:3.12-alpine@sha256:2d91681153dd4b  0.7s
#  => [agents internal] load build context                                   0.0s
# [+] Building 3.7s (12/20)
#  => => transferring dockerfile: 245B                                       0.0s
#  => [agents internal] load build definition from Dockerfile.agents         0.6s
#  => => transferring dockerfile: 218B                                       0.0s
#  => [kali internal] load build definition from Dockerfile.kali             0.4s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [mysql internal] load metadata for docker.io/library/mysql:latest      1.4s
#  => [kali internal] load metadata for docker.io/kalilinux/kali-rolling:la  1.4s
#  => [agents internal] load metadata for docker.io/library/python:3.12-alp  1.4s
#  => [mysql internal] load .dockerignore                                    0.4s
#  => => transferring context: 2B                                            0.0s
#  => [agents internal] load .dockerignore                                   0.4s
#  => => transferring context: 2B                                            0.0s
#  => [mysql internal] load build context                                    0.3s
#  => => transferring context: 39B                                           0.0s
#  => [mysql 1/2] FROM docker.io/library/mysql:latest@sha256:db32c8ec843c04  0.8s
#  => => resolve docker.io/library/mysql:latest@sha256:db32c8ec843c042a728e  0.8s
#  => [kali 1/3] FROM docker.io/kalilinux/kali-rolling:latest@sha256:05ac8a  0.9s
#  => => resolve docker.io/kalilinux/kali-rolling:latest@sha256:05ac8ac0620  0.8s
#  => [agents 1/4] FROM docker.io/library/python:3.12-alpine@sha256:2d91681  0.8s
#  => => resolve docker.io/library/python:3.12-alpine@sha256:2d91681153dd4b  0.8s
#  => [agents internal] load build context                                   0.0s
#  => CACHED [mysql 2/2] COPY ./init_database.sql /docker-entrypoint-initdb  0.0s
# [+] Building 3.8s (15/21)
#  => [agents internal] load build definition from Dockerfile.agents         0.6s
#  => => transferring dockerfile: 218B                                       0.0s
#  => [kali internal] load build definition from Dockerfile.kali             0.4s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [mysql internal] load metadata for docker.io/library/mysql:latest      1.4s
#  => [kali internal] load metadata for docker.io/kalilinux/kali-rolling:la  1.4s
#  => [agents internal] load metadata for docker.io/library/python:3.12-alp  1.4s
#  => [mysql internal] load .dockerignore                                    0.4s
#  => => transferring context: 2B                                            0.0s
#  => [agents internal] load .dockerignore                                   0.4s
#  => => transferring context: 2B                                            0.0s
#  => [mysql internal] load build context                                    0.3s
#  => => transferring context: 39B                                           0.0s
#  => [mysql 1/2] FROM docker.io/library/mysql:latest@sha256:db32c8ec843c04  0.8s
#  => => resolve docker.io/library/mysql:latest@sha256:db32c8ec843c042a728e  0.8s
#  => [kali 1/3] FROM docker.io/kalilinux/kali-rolling:latest@sha256:05ac8a  0.9s
#  => => resolve docker.io/kalilinux/kali-rolling:latest@sha256:05ac8ac0620  0.8s
#  => [agents 1/4] FROM docker.io/library/python:3.12-alpine@sha256:2d91681  0.9s
#  => => resolve docker.io/library/python:3.12-alpine@sha256:2d91681153dd4b  0.8s
#  => [agents internal] load build context                                   0.0s
#  => CACHED [mysql 2/2] COPY ./init_database.sql /docker-entrypoint-initdb  0.0s
#  => [mysql] exporting to image                                             0.0s
# [+] Building 3.9s (16/22)
#  => [agents internal] load .dockerignore                                   0.4s
#  => => transferring context: 2B                                            0.0s
#  => [mysql internal] load build context                                    0.3s
#  => => transferring context: 39B                                           0.0s
#  => [mysql 1/2] FROM docker.io/library/mysql:latest@sha256:db32c8ec843c04  0.8s
#  => => resolve docker.io/library/mysql:latest@sha256:db32c8ec843c042a728e  0.8s
#  => [kali 1/3] FROM docker.io/kalilinux/kali-rolling:latest@sha256:05ac8a  0.9s
#  => => resolve docker.io/kalilinux/kali-rolling:latest@sha256:05ac8ac0620  0.8s
#  => [agents 1/4] FROM docker.io/library/python:3.12-alpine@sha256:2d91681  0.9s
#  => => resolve docker.io/library/python:3.12-alpine@sha256:2d91681153dd4b  0.8s
#  => [agents internal] load build context                                   0.1s
#  => => transferring context: 28.87kB                                       0.0s
#  => CACHED [mysql 2/2] COPY ./init_database.sql /docker-entrypoint-initdb  0.0s
#  => [mysql] exporting to image                                             0.1s
#  => => exporting layers                                                    0.0s
#  => => exporting manifest sha256:45cee18ff6b5cb671622412b289fbf2f882ea578  0.1s
#  => => exporting config sha256:dfa033d6c9f230948505f360562524ea8214029811  0.0s
#  => CACHED [kali 2/3] RUN apt-get update &&     apt-get install -y --no-i  0.0s
#  => CACHED [kali 3/3] WORKDIR /root                                        0.0s
#  => [kali] exporting to image                                              0.1s
#  => => exporting layers                                                    0.0s
#  => => exporting manifest sha256:e072d68e8f919b6fcd5c5bbdcad48cb3d1001a2c  0.1s
# [+] Building 4.1s (16/22)
#  => => transferring context: 2B                                            0.0s
#  => [mysql internal] load build context                                    0.3s
#  => => transferring context: 39B                                           0.0s
#  => [mysql 1/2] FROM docker.io/library/mysql:latest@sha256:db32c8ec843c04  0.8s
#  => => resolve docker.io/library/mysql:latest@sha256:db32c8ec843c042a728e  0.8s
#  => [kali 1/3] FROM docker.io/kalilinux/kali-rolling:latest@sha256:05ac8a  0.9s
#  => => resolve docker.io/kalilinux/kali-rolling:latest@sha256:05ac8ac0620  0.8s
#  => [agents 1/4] FROM docker.io/library/python:3.12-alpine@sha256:2d91681  0.9s
#  => => resolve docker.io/library/python:3.12-alpine@sha256:2d91681153dd4b  0.8s
#  => [agents internal] load build context                                   0.3s
#  => => transferring context: 28.87kB                                       0.0s
#  => CACHED [mysql 2/2] COPY ./init_database.sql /docker-entrypoint-initdb  0.0s
#  => [mysql] exporting to image                                             0.3s
#  => => exporting layers                                                    0.0s
#  => => exporting manifest sha256:45cee18ff6b5cb671622412b289fbf2f882ea578  0.1s
#  => => exporting config sha256:dfa033d6c9f230948505f360562524ea8214029811  0.2s
#  => CACHED [kali 2/3] RUN apt-get update &&     apt-get install -y --no-i  0.0s
#  => CACHED [kali 3/3] WORKDIR /root                                        0.0s
#  => [kali] exporting to image                                              0.3s
#  => => exporting layers                                                    0.0s
#  => => exporting manifest sha256:e072d68e8f919b6fcd5c5bbdcad48cb3d1001a2c  0.1s
#  => => exporting config sha256:7ff452ce5478b6dcf947d13f9ca8bb2e6657c6bb90  0.1s
# [+] Building 4.3s (18/22)
#  => => transferring context: 39B                                           0.0s
#  => [mysql 1/2] FROM docker.io/library/mysql:latest@sha256:db32c8ec843c04  0.8s
#  => => resolve docker.io/library/mysql:latest@sha256:db32c8ec843c042a728e  0.8s
#  => [kali 1/3] FROM docker.io/kalilinux/kali-rolling:latest@sha256:05ac8a  0.9s
#  => => resolve docker.io/kalilinux/kali-rolling:latest@sha256:05ac8ac0620  0.8s
#  => [agents 1/4] FROM docker.io/library/python:3.12-alpine@sha256:2d91681  0.9s
#  => => resolve docker.io/library/python:3.12-alpine@sha256:2d91681153dd4b  0.8s
#  => [agents internal] load build context                                   0.3s
#  => => transferring context: 28.87kB                                       0.0s
#  => CACHED [mysql 2/2] COPY ./init_database.sql /docker-entrypoint-initdb  0.0s
#  => [mysql] exporting to image                                             0.5s
#  => => exporting layers                                                    0.0s
#  => => exporting manifest sha256:45cee18ff6b5cb671622412b289fbf2f882ea578  0.1s
#  => => exporting config sha256:dfa033d6c9f230948505f360562524ea8214029811  0.2s
#  => CACHED [kali 2/3] RUN apt-get update &&     apt-get install -y --no-i  0.0s
#  => CACHED [kali 3/3] WORKDIR /root                                        0.0s
#  => [kali] exporting to image                                              0.5s
#  => => exporting layers                                                    0.0s
#  => => exporting manifest sha256:e072d68e8f919b6fcd5c5bbdcad48cb3d1001a2c  0.1s
#  => => exporting config sha256:7ff452ce5478b6dcf947d13f9ca8bb2e6657c6bb90  0.1s
#  => CACHED [agents 2/4] WORKDIR /app                                       0.0s
#  => [agents 3/4] COPY ./ai /app                                            0.2s
# [+] Building 4.4s (18/22)
#  => => transferring context: 39B                                           0.0s
#  => [mysql 1/2] FROM docker.io/library/mysql:latest@sha256:db32c8ec843c04  0.8s
#  => => resolve docker.io/library/mysql:latest@sha256:db32c8ec843c042a728e  0.8s
#  => [kali 1/3] FROM docker.io/kalilinux/kali-rolling:latest@sha256:05ac8a  0.9s
#  => => resolve docker.io/kalilinux/kali-rolling:latest@sha256:05ac8ac0620  0.8s
#  => [agents 1/4] FROM docker.io/library/python:3.12-alpine@sha256:2d91681  0.9s
#  => => resolve docker.io/library/python:3.12-alpine@sha256:2d91681153dd4b  0.8s
#  => [agents internal] load build context                                   0.3s
#  => => transferring context: 28.87kB                                       0.0s
#  => CACHED [mysql 2/2] COPY ./init_database.sql /docker-entrypoint-initdb  0.0s
#  => [mysql] exporting to image                                             0.7s
#  => => exporting layers                                                    0.0s
#  => => exporting manifest sha256:45cee18ff6b5cb671622412b289fbf2f882ea578  0.1s
#  => => exporting config sha256:dfa033d6c9f230948505f360562524ea8214029811  0.2s
#  => CACHED [kali 2/3] RUN apt-get update &&     apt-get install -y --no-i  0.0s
#  => CACHED [kali 3/3] WORKDIR /root                                        0.0s
#  => [kali] exporting to image                                              0.6s
#  => => exporting layers                                                    0.0s
#  => => exporting manifest sha256:e072d68e8f919b6fcd5c5bbdcad48cb3d1001a2c  0.1s
#  => => exporting config sha256:7ff452ce5478b6dcf947d13f9ca8bb2e6657c6bb90  0.1s
#  => CACHED [agents 2/4] WORKDIR /app                                       0.0s
#  => [agents 3/4] COPY ./ai /app                                            0.3s
# [+] Building 4.6s (18/22)
#  => => transferring context: 39B                                           0.0s
#  => [mysql 1/2] FROM docker.io/library/mysql:latest@sha256:db32c8ec843c04  0.8s
#  => => resolve docker.io/library/mysql:latest@sha256:db32c8ec843c042a728e  0.8s
#  => [kali 1/3] FROM docker.io/kalilinux/kali-rolling:latest@sha256:05ac8a  0.9s
#  => => resolve docker.io/kalilinux/kali-rolling:latest@sha256:05ac8ac0620  0.8s
#  => [agents 1/4] FROM docker.io/library/python:3.12-alpine@sha256:2d91681  0.9s
#  => => resolve docker.io/library/python:3.12-alpine@sha256:2d91681153dd4b  0.8s
#  => [agents internal] load build context                                   0.3s
#  => => transferring context: 28.87kB                                       0.0s
#  => CACHED [mysql 2/2] COPY ./init_database.sql /docker-entrypoint-initdb  0.0s
#  => [mysql] exporting to image                                             0.8s
#  => => exporting layers                                                    0.0s
#  => => exporting manifest sha256:45cee18ff6b5cb671622412b289fbf2f882ea578  0.1s
#  => => exporting config sha256:dfa033d6c9f230948505f360562524ea8214029811  0.2s
#  => CACHED [kali 2/3] RUN apt-get update &&     apt-get install -y --no-i  0.0s
#  => CACHED [kali 3/3] WORKDIR /root                                        0.0s
#  => [kali] exporting to image                                              0.8s
#  => => exporting layers                                                    0.0s
#  => => exporting manifest sha256:e072d68e8f919b6fcd5c5bbdcad48cb3d1001a2c  0.1s
#  => => exporting config sha256:7ff452ce5478b6dcf947d13f9ca8bb2e6657c6bb90  0.1s
#  => CACHED [agents 2/4] WORKDIR /app                                       0.0s
#  => [agents 3/4] COPY ./ai /app                                            0.5s
# [+] Building 4.6s (18/22)
#  => [mysql 1/2] FROM docker.io/library/mysql:latest@sha256:db32c8ec843c04  0.8s
#  => => resolve docker.io/library/mysql:latest@sha256:db32c8ec843c042a728e  0.8s
#  => [kali 1/3] FROM docker.io/kalilinux/kali-rolling:latest@sha256:05ac8a  0.9s
#  => => resolve docker.io/kalilinux/kali-rolling:latest@sha256:05ac8ac0620  0.8s
#  => [agents 1/4] FROM docker.io/library/python:3.12-alpine@sha256:2d91681  0.9s
#  => => resolve docker.io/library/python:3.12-alpine@sha256:2d91681153dd4b  0.8s
#  => [agents internal] load build context                                   0.3s
#  => => transferring context: 28.87kB                                       0.0s
#  => CACHED [mysql 2/2] COPY ./init_database.sql /docker-entrypoint-initdb  0.0s
#  => [mysql] exporting to image                                             0.9s
#  => => exporting layers                                                    0.0s
#  => => exporting manifest sha256:45cee18ff6b5cb671622412b289fbf2f882ea578  0.1s
#  => => exporting config sha256:dfa033d6c9f230948505f360562524ea8214029811  0.2s
#  => => exporting attestation manifest sha256:7cd98e08357b811b44b534b89b24  0.0s
#  => CACHED [kali 2/3] RUN apt-get update &&     apt-get install -y --no-i  0.0s
#  => CACHED [kali 3/3] WORKDIR /root                                        0.0s
#  => [kali] exporting to image                                              0.8s
#  => => exporting layers                                                    0.0s
#  => => exporting manifest sha256:e072d68e8f919b6fcd5c5bbdcad48cb3d1001a2c  0.1s
#  => => exporting config sha256:7ff452ce5478b6dcf947d13f9ca8bb2e6657c6bb90  0.1s
#  => CACHED [agents 2/4] WORKDIR /app                                       0.0s
#  => [agents 3/4] COPY ./ai /app                                            0.5s
# [+] Building 4.8s (18/22)
#  => => resolve docker.io/library/mysql:latest@sha256:db32c8ec843c042a728e  0.8s
#  => [kali 1/3] FROM docker.io/kalilinux/kali-rolling:latest@sha256:05ac8a  0.9s
#  => => resolve docker.io/kalilinux/kali-rolling:latest@sha256:05ac8ac0620  0.8s
#  => [agents 1/4] FROM docker.io/library/python:3.12-alpine@sha256:2d91681  0.9s
#  => => resolve docker.io/library/python:3.12-alpine@sha256:2d91681153dd4b  0.8s
#  => [agents internal] load build context                                   0.3s
#  => => transferring context: 28.87kB                                       0.0s
#  => CACHED [mysql 2/2] COPY ./init_database.sql /docker-entrypoint-initdb  0.0s
#  => [mysql] exporting to image                                             1.0s
#  => => exporting layers                                                    0.0s
#  => => exporting manifest sha256:45cee18ff6b5cb671622412b289fbf2f882ea578  0.1s
#  => => exporting config sha256:dfa033d6c9f230948505f360562524ea8214029811  0.2s
#  => => exporting attestation manifest sha256:7cd98e08357b811b44b534b89b24  0.1s
#  => CACHED [kali 2/3] RUN apt-get update &&     apt-get install -y --no-i  0.0s
#  => CACHED [kali 3/3] WORKDIR /root                                        0.0s
#  => [kali] exporting to image                                              1.0s
#  => => exporting layers                                                    0.0s
#  => => exporting manifest sha256:e072d68e8f919b6fcd5c5bbdcad48cb3d1001a2c  0.1s
#  => => exporting config sha256:7ff452ce5478b6dcf947d13f9ca8bb2e6657c6bb90  0.1s
#  => => exporting attestation manifest sha256:c439d0b4f1e1e0da932273bb5f6f  0.0s
#  => CACHED [agents 2/4] WORKDIR /app                                       0.0s
#  => [agents 3/4] COPY ./ai /app                                            0.7s
# [+] Building 4.9s (18/22)
#  => => resolve docker.io/library/mysql:latest@sha256:db32c8ec843c042a728e  0.8s
#  => [kali 1/3] FROM docker.io/kalilinux/kali-rolling:latest@sha256:05ac8a  0.9s
#  => => resolve docker.io/kalilinux/kali-rolling:latest@sha256:05ac8ac0620  0.8s
#  => [agents 1/4] FROM docker.io/library/python:3.12-alpine@sha256:2d91681  0.9s
#  => => resolve docker.io/library/python:3.12-alpine@sha256:2d91681153dd4b  0.8s
#  => [agents internal] load build context                                   0.3s
#  => => transferring context: 28.87kB                                       0.0s
#  => CACHED [mysql 2/2] COPY ./init_database.sql /docker-entrypoint-initdb  0.0s
#  => [mysql] exporting to image                                             1.1s
#  => => exporting layers                                                    0.0s
#  => => exporting manifest sha256:45cee18ff6b5cb671622412b289fbf2f882ea578  0.1s
#  => => exporting config sha256:dfa033d6c9f230948505f360562524ea8214029811  0.2s
#  => => exporting attestation manifest sha256:7cd98e08357b811b44b534b89b24  0.3s
# ...
#  ✔ Container webui            Created                                      1.0s
# [+] up 10/10
#  ✔ Image agent-image          Built                                        80.3s
#  ✔ Image kali-image           Built                                        80.3s
#  ✔ Image sql-image            Built                                        80.3s
#  ✔ Network ci-attacks_billnet Created                                      0.2s
#  ✔ Container ollama           Created                                      3.6s
#  ✔ Container mysql            Created                                      4.2s
#  ✔ Container tedmed           Created                                      4.5s
#  ✔ Container kali             Created                                      3.2s
#  ✔ Container agents           Created                                      1.5s
#  ✔ Container webui            Created                                      1.0s
# [+] up 10/10
#  ✔ Image agent-image          Built                                        80.3s
#  ✔ Image kali-image           Built                                        80.3s
#  ✔ Image sql-image            Built                                        80.3s
#  ✔ Network ci-attacks_billnet Created                                      0.2s
#  ✔ Container ollama           Created                                      3.6s
#  ✔ Container mysql            Created                                      4.2s
#  ✔ Container tedmed           Created                                      4.5s
#  ✔ Container kali             Created                                      3.2s
#  ✔ Container agents           Created                                      1.5s
#  ✔ Container webui            Created                                      1.0s
# [+] up 10/10
#  ✔ Image agent-image          Built                                        80.3s
#  ✔ Image kali-image           Built                                        80.3s
#  ✔ Image sql-image            Built                                        80.3s
#  ✔ Network ci-attacks_billnet Created                                      0.2s
#  ✔ Container ollama           Created                                      3.6s
#  ✔ Container mysql            Created                                      4.2s
#  ✔ Container tedmed           Created                                      4.5s
#  ✔ Container kali             Created                                      3.2s
#  ✔ Container agents           Created                                      1.5s
#  ✔ Container webui            Created                                      1.0s
# [+] up 10/10
#  ✔ Image agent-image          Built                                        80.3s
#  ✔ Image kali-image           Built                                        80.3s
#  ✔ Image sql-image            Built                                        80.3s
#  ✔ Network ci-attacks_billnet Created                                      0.2s
#  ✔ Container ollama           Created                                      3.6s
#  ✔ Container mysql            Created                                      4.2s
#  ✔ Container tedmed           Created                                      4.5s
#  ✔ Container kali             Created                                      3.2s
#  ✔ Container agents           Created                                      1.5s
#  ✔ Container webui            Created                                      1.0s
# [+] up 10/10
#  ✔ Image agent-image          Built                                        80.3s
#  ✔ Image kali-image           Built                                        80.3s
#  ✔ Image sql-image            Built                                        80.3s
#  ✔ Network ci-attacks_billnet Created                                      0.2s
#  ✔ Container ollama           Created                                      3.6s
#  ✔ Container mysql            Created                                      4.2s
#  ✔ Container tedmed           Created                                      4.5s
#  ✔ Container kali             Created                                      3.2s
#  ✔ Container agents           Created                                      1.5s
#  ✔ Container webui            Created                                      1.0s
# [+] up 10/10
#  ✔ Image agent-image          Built                                        80.3s
#  ✔ Image kali-image           Built                                        80.3s
#  ✔ Image sql-image            Built                                        80.3s
#  ✔ Network ci-attacks_billnet Created                                      0.2s
#  ✔ Container ollama           Created                                      3.6s
#  ✔ Container mysql            Created                                      4.2s
#  ✔ Container tedmed           Created                                      4.5s
#  ✔ Container kali             Created                                      3.2s
#  ✔ Container agents           Created                                      1.5s
#  ✔ Container webui            Created                                      1.0s
# [+] up 10/10
#  ✔ Image agent-image          Built                                        80.3s
#  ✔ Image kali-image           Built                                        80.3s
#  ✔ Image sql-image            Built                                        80.3s
#  ✔ Network ci-attacks_billnet Created                                      0.2s
#  ✔ Container ollama           Created                                      3.6s
#  ✔ Container mysql            Created                                      4.2s
#  ✔ Container tedmed           Created                                      4.5s
#  ✔ Container kali             Created                                      3.2s
#  ✔ Container agents           Created                                      1.5s
#  ✔ Container webui            Created                                      1.0s
# [+] up 10/10
#  ✔ Image agent-image          Built                                        80.3s
#  ✔ Image kali-image           Built                                        80.3s
#  ✔ Image sql-image            Built                                        80.3s
#  ✔ Network ci-attacks_billnet Created                                      0.2s
#  ✔ Container ollama           Created                                      3.6s
#  ✔ Container mysql            Created                                      4.2s
#  ✔ Container tedmed           Created                                      4.5s
#  ✔ Container kali             Created                                      3.2s
#  ✔ Container agents           Created                                      1.5s
#  ✔ Container webui            Created                                      1.0s
# [+] up 10/10
#  ✔ Image agent-image          Built                                        80.3s
#  ✔ Image kali-image           Built                                        80.3s
#  ✔ Image sql-image            Built                                        80.3s
#  ✔ Network ci-attacks_billnet Created                                      0.2s
#  ✔ Container ollama           Created                                      3.6s
#  ✔ Container mysql            Created                                      4.2s
#  ✔ Container tedmed           Created                                      4.5s
#  ✔ Container kali             Created                                      3.2s
#  ✔ Container agents           Created                                      1.5s
#  ✔ Container webui            Created                                      1.0s
# [+] up 10/10
#  ✔ Image agent-image          Built                                        80.3s
#  ✔ Image kali-image           Built                                        80.3s
#  ✔ Image sql-image            Built                                        80.3s
#  ✔ Network ci-attacks_billnet Created                                      0.2s
#  ✔ Container ollama           Created                                      3.6s
#  ✔ Container mysql            Created                                      4.2s
#  ✔ Container tedmed           Created                                      4.5s
#  ✔ Container kali             Created                                      3.2s
#  ✔ Container agents           Created                                      1.5s
#  ✔ Container webui            Created                                      1.0s
# [+] up 10/10
#  ✔ Image agent-image          Built                                        80.3s
#  ✔ Image kali-image           Built                                        80.3s
#  ✔ Image sql-image            Built                                        80.3s
#  ✔ Network ci-attacks_billnet Created                                      0.2s
#  ✔ Container ollama           Created                                      3.6s
#  ✔ Container mysql            Created                                      4.2s
#  ✔ Container tedmed           Created                                      4.5s
#  ✔ Container kali             Created                                      3.2s
#  ✔ Container agents           Created                                      1.5s
#  ✔ Container webui            Created                                      1.0s
# [+] up 10/10
#  ✔ Image agent-image          Built                                        80.3s
#  ✔ Image kali-image           Built                                        80.3s
#  ✔ Image sql-image            Built                                        80.3s
#  ✔ Network ci-attacks_billnet Created                                      0.2s
#  ✔ Container ollama           Created                                      3.6s
#  ✔ Container mysql            Created                                      4.2s
#  ✔ Container tedmed           Created                                      4.5s
#  ✔ Container kali             Created                                      3.2s
#  ✔ Container agents           Created                                      1.5s
#  ✔ Container webui            Created                                      1.0s
# [+] up 10/10
#  ✔ Image agent-image          Built                                        80.3s
#  ✔ Image kali-image           Built                                        80.3s
#  ✔ Image sql-image            Built                                        80.3s
#  ✔ Network ci-attacks_billnet Created                                      0.2s
#  ✔ Container ollama           Created                                      3.6s
#  ✔ Container mysql            Created                                      4.2s
#  ✔ Container tedmed           Created                                      4.5s
#  ✔ Container kali             Created                                      3.2s
#  ✔ Container agents           Created                                      1.5s
#  ✔ Container webui            Created                                      1.0s
# [+] up 10/10
#  ✔ Image agent-image          Built                                        80.3s
#  ✔ Image kali-image           Built                                        80.3s
#  ✔ Image sql-image            Built                                        80.3s
#  ✔ Network ci-attacks_billnet Created                                      0.2s
#  ✔ Container ollama           Created                                      3.6s
#  ✔ Container mysql            Created                                      4.2s
#  ✔ Container tedmed           Created                                      4.5s
#  ✔ Container kali             Created                                      3.2s
#  ✔ Container agents           Created                                      1.5s
#  ✔ Container webui            Created                                      1.0s
# [+] up 10/10
#  ✔ Image agent-image          Built                                        80.3s
#  ✔ Image kali-image           Built                                        80.3s
#  ✔ Image sql-image            Built                                        80.3s
#  ✔ Network ci-attacks_billnet Created                                      0.2s
#  ✔ Container ollama           Created                                      3.6s
#  ✔ Container mysql            Created                                      4.2s
#  ✔ Container tedmed           Created                                      4.5s
#  ✔ Container kali             Created                                      3.2s
#  ✔ Container agents           Created                                      1.5s
#  ✔ Container webui            Created                                      1.0s
# [+] up 10/10
#  ✔ Image agent-image          Built                                        80.3s
#  ✔ Image kali-image           Built                                        80.3s
#  ✔ Image sql-image            Built                                        80.3s
#  ✔ Network ci-attacks_billnet Created                                      0.2s
#  ✔ Container ollama           Created                                      3.6s
#  ✔ Container mysql            Created                                      4.2s
#  ✔ Container tedmed           Created                                      4.5s
#  ✔ Container kali             Created                                      3.2s
#  ✔ Container agents           Created                                      1.5s
#  ✔ Container webui            Created                                      1.0s
# [+] up 10/10
#  ✔ Image agent-image          Built                                        80.3s
#  ✔ Image kali-image           Built                                        80.3s
#  ✔ Image sql-image            Built                                        80.3s
#  ✔ Network ci-attacks_billnet Created                                      0.2s
#  ✔ Container ollama           Created                                      3.6s
#  ✔ Container mysql            Created                                      4.2s
#  ✔ Container tedmed           Created                                      4.5s
#  ✔ Container kali             Created                                      3.2s
#  ✔ Container agents           Created                                      1.5s
#  ✔ Container webui            Created                                      1.0s
# [+] up 10/10
#  ✔ Image agent-image          Built                                        80.3s
#  ✔ Image kali-image           Built                                        80.3s
#  ✔ Image sql-image            Built                                        80.3s
#  ✔ Network ci-attacks_billnet Created                                      0.2s
#  ✔ Container ollama           Created                                      3.6s
#  ✔ Container mysql            Created                                      4.2s
#  ✔ Container tedmed           Created                                      4.5s
#  ✔ Container kali             Created                                      3.2s
#  ✔ Container agents           Created                                      1.5s
#  ✔ Container webui            Created                                      1.0s
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest
# pulling 2049f5674b1e: 100% ▕██████████████████▏ 9.0 GB
# pulling 66b9ea09bd5b: 100% ▕██████████████████▏   68 B
# pulling eb4402837c78: 100% ▕██████████████████▏ 1.5 KB
# pulling 832dd9e00a68: 100% ▕██████████████████▏  11 KB
# pulling db59b814cab7: 100% ▕██████████████████▏  488 B
# verifying sha256 digest
# writing manifest
# success

# %% [markdown]
# # List Running Containers
#
# Run this cell to verify all of the containers are up and running.
#
# There should be 6 containers running:
# - mysql
# - webui
# - kali
# - agents
# - ollama
# - tedmed
#
# Once the webui container is active (this usually takes a few seconds longer than the rest of the containers), navigate to `http://localhost:3000` in your browser to access the WebUI.
# Log into WebUI with one of these mock users:
# | email           | password |
# |-------------------|----------|
# | alice@example.com |password |
# | bob@example.com   | password |
# | carol@example.com | password |
# | david@example.com | password |
# | eve@example.com   | password |
# To view the Ted Med Talk blog page, navigate to `http://localhost:8080`.

# %%
# !docker ps
# Out:
# CONTAINER ID   IMAGE                                COMMAND                  CREATED         STATUS                   PORTS                               NAMES
# 271fbd443370   ghcr.io/open-webui/open-webui:main   "bash start.sh"          3 minutes ago   Up 2 minutes (healthy)   0.0.0.0:2010->8080/tcp              webui
# 08d206ea61f7   agent-image                          "uvicorn app:app --h…"   3 minutes ago   Up 3 minutes             0.0.0.0:2012->8000/tcp              agents
# 8cec8e7beba0   nginx:stable-alpine                  "/docker-entrypoint.…"   3 minutes ago   Up 3 minutes             0.0.0.0:2014->80/tcp                tedmed
# 0c37ddb5f07e   sql-image                            "docker-entrypoint.s…"   3 minutes ago   Up 3 minutes             33060/tcp, 0.0.0.0:2013->3306/tcp   mysql
# e4f18d830ae6   ollama/ollama:latest                 "/bin/ollama serve"      3 minutes ago   Up 3 minutes             0.0.0.0:2011->11434/tcp             ollama
# 83842aca997b   kali-image                           "bash"                   3 minutes ago   Up 3 minutes                                                 kali

# %% [markdown]
# ## View AI Container Logs
#
# Run this cell to view the logs of the AI container

# %%
# !docker logs agents -f
# Out:
# Error response from daemon: No such container: agents

# %% [markdown]
# ## Shut Down Containers
#
# Run this cell to stop and remove all running containers

# %%
# !docker compose down
