# %% [markdown]
# # Run System
#
# This notebook contains all of the necessary commands to start up the Docker network and run the WebUI
#
# ## Start Containers and Pull Ollama Model
#
# Run this cell to start up all of the containers in the network and pull the qwen2.5:14b model to the Ollama container.
#
# If this is your first time running the system, it may take 5-10 minutes to pull each of the Docker images and the Qwen model.
#
# Subsequent startups should only take a few seconds.

# %%
# !bash setup.sh
# !docker compose up -d --build
# !docker exec -it ollama ollama pull qwen2.5:14b
#!docker exec -it ollama ollama create llm -f ./root/.ollama/Modelfile
#!docker exec -it ollama ollama run qwen
# Out:
# [+] Building 0.0s (0/1)
#  => [internal] load local bake definitions                                 0.0s
# [+] Building 0.2s (1/1)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 1.64kB                                           0.0s
# [+] Building 0.3s (1/1)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 1.64kB                                           0.0s
# [+] Building 0.3s (1/2)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 1.64kB                                           0.0s
# [+] Building 0.4s (1/4)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 1.64kB                                           0.0s
#  => [kali internal] load build definition from Dockerfile.kali             0.1s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [mysql internal] load build definition from Dockerfile.database        0.1s
#  => [agents internal] load build definition from Dockerfile.agents         0.1s
#  => => transferring dockerfile:                                            0.0s
# [+] Building 0.6s (2/4)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 1.64kB                                           0.0s
#  => [kali internal] load build definition from Dockerfile.kali             0.3s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [mysql internal] load build definition from Dockerfile.database        0.3s
#  => => transferring dockerfile: 245B                                       0.0s
#  => [agents internal] load build definition from Dockerfile.agents         0.3s
#  => => transferring dockerfile: 218B                                       0.0s
# [+] Building 0.8s (3/5)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 1.64kB                                           0.0s
#  => [kali internal] load build definition from Dockerfile.kali             0.3s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [mysql internal] load build definition from Dockerfile.database        0.4s
#  => => transferring dockerfile: 245B                                       0.0s
#  => [agents internal] load build definition from Dockerfile.agents         0.4s
#  => => transferring dockerfile: 218B                                       0.0s
#  => [kali internal] load metadata for docker.io/kalilinux/kali-rolling:la  0.0s
# [+] Building 0.9s (4/7)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 1.64kB                                           0.0s
#  => [kali internal] load build definition from Dockerfile.kali             0.3s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [mysql internal] load build definition from Dockerfile.database        0.5s
#  => => transferring dockerfile: 245B                                       0.0s
#  => [agents internal] load build definition from Dockerfile.agents         0.4s
#  => => transferring dockerfile: 218B                                       0.0s
#  => [kali internal] load metadata for docker.io/kalilinux/kali-rolling:la  0.2s
#  => [agents internal] load metadata for docker.io/library/python:3.12-alp  0.1s
#  => [mysql internal] load metadata for docker.io/library/mysql:latest      0.0s
# [+] Building 1.1s (4/7)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 1.64kB                                           0.0s
#  => [kali internal] load build definition from Dockerfile.kali             0.3s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [mysql internal] load build definition from Dockerfile.database        0.5s
#  => => transferring dockerfile: 245B                                       0.0s
#  => [agents internal] load build definition from Dockerfile.agents         0.4s
#  => => transferring dockerfile: 218B                                       0.0s
#  => [kali internal] load metadata for docker.io/kalilinux/kali-rolling:la  0.3s
#  => [agents internal] load metadata for docker.io/library/python:3.12-alp  0.2s
#  => [mysql internal] load metadata for docker.io/library/mysql:latest      0.2s
# [+] Building 1.2s (4/7)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 1.64kB                                           0.0s
#  => [kali internal] load build definition from Dockerfile.kali             0.3s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [mysql internal] load build definition from Dockerfile.database        0.5s
#  => => transferring dockerfile: 245B                                       0.0s
#  => [agents internal] load build definition from Dockerfile.agents         0.4s
#  => => transferring dockerfile: 218B                                       0.0s
#  => [kali internal] load metadata for docker.io/kalilinux/kali-rolling:la  0.5s
#  => [agents internal] load metadata for docker.io/library/python:3.12-alp  0.4s
#  => [mysql internal] load metadata for docker.io/library/mysql:latest      0.3s
# [+] Building 1.4s (4/7)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 1.64kB                                           0.0s
#  => [kali internal] load build definition from Dockerfile.kali             0.3s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [mysql internal] load build definition from Dockerfile.database        0.5s
#  => => transferring dockerfile: 245B                                       0.0s
#  => [agents internal] load build definition from Dockerfile.agents         0.4s
#  => => transferring dockerfile: 218B                                       0.0s
#  => [kali internal] load metadata for docker.io/kalilinux/kali-rolling:la  0.6s
#  => [agents internal] load metadata for docker.io/library/python:3.12-alp  0.5s
#  => [mysql internal] load metadata for docker.io/library/mysql:latest      0.5s
# [+] Building 1.5s (4/7)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 1.64kB                                           0.0s
#  => [kali internal] load build definition from Dockerfile.kali             0.3s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [mysql internal] load build definition from Dockerfile.database        0.5s
#  => => transferring dockerfile: 245B                                       0.0s
#  => [agents internal] load build definition from Dockerfile.agents         0.4s
#  => => transferring dockerfile: 218B                                       0.0s
#  => [kali internal] load metadata for docker.io/kalilinux/kali-rolling:la  0.8s
#  => [agents internal] load metadata for docker.io/library/python:3.12-alp  0.7s
#  => [mysql internal] load metadata for docker.io/library/mysql:latest      0.6s
# [+] Building 1.7s (4/7)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 1.64kB                                           0.0s
#  => [kali internal] load build definition from Dockerfile.kali             0.3s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [mysql internal] load build definition from Dockerfile.database        0.5s
#  => => transferring dockerfile: 245B                                       0.0s
#  => [agents internal] load build definition from Dockerfile.agents         0.4s
#  => => transferring dockerfile: 218B                                       0.0s
#  => [kali internal] load metadata for docker.io/kalilinux/kali-rolling:la  0.9s
#  => [agents internal] load metadata for docker.io/library/python:3.12-alp  0.8s
#  => [mysql internal] load metadata for docker.io/library/mysql:latest      0.8s
# [+] Building 1.8s (4/7)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 1.64kB                                           0.0s
#  => [kali internal] load build definition from Dockerfile.kali             0.3s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [mysql internal] load build definition from Dockerfile.database        0.5s
#  => => transferring dockerfile: 245B                                       0.0s
#  => [agents internal] load build definition from Dockerfile.agents         0.4s
#  => => transferring dockerfile: 218B                                       0.0s
#  => [kali internal] load metadata for docker.io/kalilinux/kali-rolling:la  1.1s
#  => [agents internal] load metadata for docker.io/library/python:3.12-alp  1.0s
#  => [mysql internal] load metadata for docker.io/library/mysql:latest      0.9s
# [+] Building 2.0s (4/7)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 1.64kB                                           0.0s
#  => [kali internal] load build definition from Dockerfile.kali             0.3s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [mysql internal] load build definition from Dockerfile.database        0.5s
#  => => transferring dockerfile: 245B                                       0.0s
#  => [agents internal] load build definition from Dockerfile.agents         0.4s
#  => => transferring dockerfile: 218B                                       0.0s
#  => [kali internal] load metadata for docker.io/kalilinux/kali-rolling:la  1.2s
#  => [agents internal] load metadata for docker.io/library/python:3.12-alp  1.1s
#  => [mysql internal] load metadata for docker.io/library/mysql:latest      1.1s
# [+] Building 2.1s (4/7)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 1.64kB                                           0.0s
#  => [kali internal] load build definition from Dockerfile.kali             0.3s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [mysql internal] load build definition from Dockerfile.database        0.5s
#  => => transferring dockerfile: 245B                                       0.0s
#  => [agents internal] load build definition from Dockerfile.agents         0.4s
#  => => transferring dockerfile: 218B                                       0.0s
#  => [kali internal] load metadata for docker.io/kalilinux/kali-rolling:la  1.4s
#  => [agents internal] load metadata for docker.io/library/python:3.12-alp  1.3s
#  => [mysql internal] load metadata for docker.io/library/mysql:latest      1.2s
# [+] Building 2.3s (4/7)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 1.64kB                                           0.0s
#  => [kali internal] load build definition from Dockerfile.kali             0.3s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [mysql internal] load build definition from Dockerfile.database        0.5s
#  => => transferring dockerfile: 245B                                       0.0s
#  => [agents internal] load build definition from Dockerfile.agents         0.4s
#  => => transferring dockerfile: 218B                                       0.0s
#  => [kali internal] load metadata for docker.io/kalilinux/kali-rolling:la  1.5s
#  => [agents internal] load metadata for docker.io/library/python:3.12-alp  1.4s
#  => [mysql internal] load metadata for docker.io/library/mysql:latest      1.4s
# [+] Building 2.4s (5/7)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 1.64kB                                           0.0s
#  => [kali internal] load build definition from Dockerfile.kali             0.3s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [mysql internal] load build definition from Dockerfile.database        0.5s
#  => => transferring dockerfile: 245B                                       0.0s
#  => [agents internal] load build definition from Dockerfile.agents         0.4s
#  => => transferring dockerfile: 218B                                       0.0s
#  => [kali internal] load metadata for docker.io/kalilinux/kali-rolling:la  1.7s
#  => [agents internal] load metadata for docker.io/library/python:3.12-alp  1.6s
#  => [mysql internal] load metadata for docker.io/library/mysql:latest      1.5s
# [+] Building 2.6s (5/8)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 1.64kB                                           0.0s
#  => [kali internal] load build definition from Dockerfile.kali             0.3s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [mysql internal] load build definition from Dockerfile.database        0.5s
#  => => transferring dockerfile: 245B                                       0.0s
#  => [agents internal] load build definition from Dockerfile.agents         0.4s
#  => => transferring dockerfile: 218B                                       0.0s
#  => [kali internal] load metadata for docker.io/kalilinux/kali-rolling:la  1.8s
#  => [agents internal] load metadata for docker.io/library/python:3.12-alp  1.7s
#  => [mysql internal] load metadata for docker.io/library/mysql:latest      1.5s
#  => [mysql internal] load .dockerignore                                    0.1s
#  => => transferring context:                                               0.0s
# [+] Building 2.7s (6/8)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 1.64kB                                           0.0s
#  => [kali internal] load build definition from Dockerfile.kali             0.3s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [mysql internal] load build definition from Dockerfile.database        0.5s
#  => => transferring dockerfile: 245B                                       0.0s
#  => [agents internal] load build definition from Dockerfile.agents         0.4s
#  => => transferring dockerfile: 218B                                       0.0s
#  => [kali internal] load metadata for docker.io/kalilinux/kali-rolling:la  1.9s
#  => [agents internal] load metadata for docker.io/library/python:3.12-alp  1.8s
#  => [mysql internal] load metadata for docker.io/library/mysql:latest      1.5s
#  => [mysql internal] load .dockerignore                                    0.3s
#  => => transferring context: 2B                                            0.0s
# [+] Building 2.8s (8/9)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 1.64kB                                           0.0s
#  => [kali internal] load build definition from Dockerfile.kali             0.3s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [mysql internal] load build definition from Dockerfile.database        0.5s
#  => => transferring dockerfile: 245B                                       0.0s
#  => [agents internal] load build definition from Dockerfile.agents         0.4s
#  => => transferring dockerfile: 218B                                       0.0s
#  => [kali internal] load metadata for docker.io/kalilinux/kali-rolling:la  1.9s
#  => [agents internal] load metadata for docker.io/library/python:3.12-alp  2.0s
#  => [mysql internal] load metadata for docker.io/library/mysql:latest      1.5s
#  => [mysql internal] load .dockerignore                                    0.3s
#  => => transferring context: 2B                                            0.0s
#  => [kali internal] load .dockerignore                                     0.1s
# [+] Building 2.9s (8/12)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 1.64kB                                           0.0s
#  => [kali internal] load build definition from Dockerfile.kali             0.3s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [mysql internal] load build definition from Dockerfile.database        0.5s
#  => => transferring dockerfile: 245B                                       0.0s
#  => [agents internal] load build definition from Dockerfile.agents         0.4s
#  => => transferring dockerfile: 218B                                       0.0s
#  => [kali internal] load metadata for docker.io/kalilinux/kali-rolling:la  1.9s
#  => [agents internal] load metadata for docker.io/library/python:3.12-alp  2.0s
#  => [mysql internal] load metadata for docker.io/library/mysql:latest      1.5s
#  => [mysql internal] load .dockerignore                                    0.3s
#  => => transferring context: 2B                                            0.0s
#  => [agents internal] load .dockerignore                                   0.2s
#  => => transferring context: 2B                                            0.0s
#  => [mysql internal] load build context                                    0.1s
#  => [mysql 1/2] FROM docker.io/library/mysql:latest@sha256:db32c8ec843c04  0.1s
#  => => resolve docker.io/library/mysql:latest@sha256:db32c8ec843c042a728e  0.0s
# [+] Building 3.1s (8/12)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 1.64kB                                           0.0s
#  => [kali internal] load build definition from Dockerfile.kali             0.3s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [mysql internal] load build definition from Dockerfile.database        0.5s
#  => => transferring dockerfile: 245B                                       0.0s
#  => [agents internal] load build definition from Dockerfile.agents         0.4s
#  => => transferring dockerfile: 218B                                       0.0s
#  => [kali internal] load metadata for docker.io/kalilinux/kali-rolling:la  1.9s
#  => [agents internal] load metadata for docker.io/library/python:3.12-alp  2.0s
#  => [mysql internal] load metadata for docker.io/library/mysql:latest      1.5s
#  => [mysql internal] load .dockerignore                                    0.3s
#  => => transferring context: 2B                                            0.0s
#  => [agents internal] load .dockerignore                                   0.4s
#  => => transferring context: 2B                                            0.0s
#  => [mysql internal] load build context                                    0.3s
#  => => transferring context: 39B                                           0.0s
#  => [mysql 1/2] FROM docker.io/library/mysql:latest@sha256:db32c8ec843c04  0.3s
#  => => resolve docker.io/library/mysql:latest@sha256:db32c8ec843c042a728e  0.2s
# [+] Building 3.2s (8/12)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 1.64kB                                           0.0s
#  => [kali internal] load build definition from Dockerfile.kali             0.3s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [mysql internal] load build definition from Dockerfile.database        0.5s
#  => => transferring dockerfile: 245B                                       0.0s
#  => [agents internal] load build definition from Dockerfile.agents         0.4s
#  => => transferring dockerfile: 218B                                       0.0s
#  => [kali internal] load metadata for docker.io/kalilinux/kali-rolling:la  1.9s
#  => [agents internal] load metadata for docker.io/library/python:3.12-alp  2.0s
#  => [mysql internal] load metadata for docker.io/library/mysql:latest      1.5s
#  => [mysql internal] load .dockerignore                                    0.3s
#  => => transferring context: 2B                                            0.0s
#  => [agents internal] load .dockerignore                                   0.5s
#  => => transferring context: 2B                                            0.0s
#  => [mysql internal] load build context                                    0.3s
#  => => transferring context: 39B                                           0.0s
#  => [mysql 1/2] FROM docker.io/library/mysql:latest@sha256:db32c8ec843c04  0.3s
#  => => resolve docker.io/library/mysql:latest@sha256:db32c8ec843c042a728e  0.3s
# [+] Building 3.3s (11/15)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 1.64kB                                           0.0s
#  => [kali internal] load build definition from Dockerfile.kali             0.3s
#  => => transferring dockerfile: 314B                                       0.0s
#  => [mysql internal] load build definition from Dockerfile.database        0.5s
#  => => transferring dockerfile: 245B                                       0.0s
#  => [agents internal] load build definition from Dockerfile.agents         0.4s
#  => => transferring dockerfile: 218B                                       0.0s
#  => [kali internal] load metadata for docker.io/kalilinux/kali-rolling:la  1.9s
#  => [agents internal] load metadata for docker.io/library/python:3.12-alp  2.0s
#  => [mysql internal] load metadata for docker.io/library/mysql:latest      1.5s
#  => [mysql internal] load .dockerignore                                    0.3s
#  => => transferring context: 2B                                            0.0s
#  => [kali internal] load .dockerignore                                     0.5s
#  => => transferring context: 2B                                            0.0s
#  => [mysql internal] load build context                                    0.4s
#  => => transferring context: 39B                                           0.0s
#  => [mysql 1/2] FROM docker.io/library/mysql:latest@sha256:db32c8ec843c04  0.4s
#  => => resolve docker.io/library/mysql:latest@sha256:db32c8ec843c042a728e  0.3s
# [+] Building 3.4s (13/20)
#  => => transferring dockerfile: 314B                                       0.0s
#  => [mysql internal] load build definition from Dockerfile.database        0.5s
#  => => transferring dockerfile: 245B                                       0.0s
#  => [agents internal] load build definition from Dockerfile.agents         0.4s
#  => => transferring dockerfile: 218B                                       0.0s
#  => [kali internal] load metadata for docker.io/kalilinux/kali-rolling:la  1.9s
#  => [agents internal] load metadata for docker.io/library/python:3.12-alp  2.0s
#  => [mysql internal] load metadata for docker.io/library/mysql:latest      1.5s
#  => [mysql internal] load .dockerignore                                    0.3s
#  => => transferring context: 2B                                            0.0s
#  => [kali internal] load .dockerignore                                     0.5s
#  => => transferring context: 2B                                            0.0s
#  => [mysql internal] load build context                                    0.4s
#  => => transferring context: 39B                                           0.0s
#  => [mysql 1/2] FROM docker.io/library/mysql:latest@sha256:db32c8ec843c04  0.4s
#  => => resolve docker.io/library/mysql:latest@sha256:db32c8ec843c042a728e  0.3s
#  => [kali 1/3] FROM docker.io/kalilinux/kali-rolling:latest@sha256:60f96e  0.1s
#  => => resolve docker.io/kalilinux/kali-rolling:latest@sha256:60f96e55e47  0.0s
#  => [agents internal] load build context                                   0.0s
#  => [agents 1/4] FROM docker.io/library/python:3.12-alpine@sha256:2d91681  0.0s
#  => => resolve docker.io/library/python:3.12-alpine@sha256:2d91681153dd4b  0.0s
#  => CACHED [mysql 2/2] COPY ./init_database.sql /docker-entrypoint-initdb  0.0s
# [+] Building 3.6s (13/21)
#  => => transferring dockerfile: 218B                                       0.0s
#  => [kali internal] load metadata for docker.io/kalilinux/kali-rolling:la  1.9s
#  => [agents internal] load metadata for docker.io/library/python:3.12-alp  2.0s
#  => [mysql internal] load metadata for docker.io/library/mysql:latest      1.5s
#  => [mysql internal] load .dockerignore                                    0.3s
#  => => transferring context: 2B                                            0.0s
#  => [kali internal] load .dockerignore                                     0.5s
#  => => transferring context: 2B                                            0.0s
#  => [mysql internal] load build context                                    0.4s
#  => => transferring context: 39B                                           0.0s
#  => [mysql 1/2] FROM docker.io/library/mysql:latest@sha256:db32c8ec843c04  0.4s
#  => => resolve docker.io/library/mysql:latest@sha256:db32c8ec843c042a728e  0.3s
#  => [kali 1/3] FROM docker.io/kalilinux/kali-rolling:latest@sha256:60f96e  0.3s
#  => => resolve docker.io/kalilinux/kali-rolling:latest@sha256:60f96e55e47  0.2s
#  => [agents internal] load build context                                   0.0s
#  => [agents 1/4] FROM docker.io/library/python:3.12-alpine@sha256:2d91681  0.2s
#  => => resolve docker.io/library/python:3.12-alpine@sha256:2d91681153dd4b  0.2s
#  => CACHED [mysql 2/2] COPY ./init_database.sql /docker-entrypoint-initdb  0.0s
#  => [mysql] exporting to image                                             0.1s
#  => => exporting layers                                                    0.0s
#  => => exporting manifest sha256:45cee18ff6b5cb671622412b289fbf2f882ea578  0.1s
#  => => exporting config sha256:dfa033d6c9f230948505f360562524ea8214029811  0.0s
# [+] Building 3.7s (13/21)
#  => => transferring dockerfile: 218B                                       0.0s
#  => [kali internal] load metadata for docker.io/kalilinux/kali-rolling:la  1.9s
#  => [agents internal] load metadata for docker.io/library/python:3.12-alp  2.0s
#  => [mysql internal] load metadata for docker.io/library/mysql:latest      1.5s
#  => [mysql internal] load .dockerignore                                    0.3s
#  => => transferring context: 2B                                            0.0s
#  => [kali internal] load .dockerignore                                     0.5s
#  => => transferring context: 2B                                            0.0s
#  => [mysql internal] load build context                                    0.4s
#  => => transferring context: 39B                                           0.0s
#  => [mysql 1/2] FROM docker.io/library/mysql:latest@sha256:db32c8ec843c04  0.4s
#  => => resolve docker.io/library/mysql:latest@sha256:db32c8ec843c042a728e  0.3s
#  => [kali 1/3] FROM docker.io/kalilinux/kali-rolling:latest@sha256:60f96e  0.4s
#  => => resolve docker.io/kalilinux/kali-rolling:latest@sha256:60f96e55e47  0.4s
#  => [agents internal] load build context                                   0.0s
#  => [agents 1/4] FROM docker.io/library/python:3.12-alpine@sha256:2d91681  0.4s
#  => => resolve docker.io/library/python:3.12-alpine@sha256:2d91681153dd4b  0.3s
#  => CACHED [mysql 2/2] COPY ./init_database.sql /docker-entrypoint-initdb  0.0s
#  => [mysql] exporting to image                                             0.3s
#  => => exporting layers                                                    0.0s
#  => => exporting manifest sha256:45cee18ff6b5cb671622412b289fbf2f882ea578  0.1s
#  => => exporting config sha256:dfa033d6c9f230948505f360562524ea8214029811  0.1s
# [+] Building 3.9s (13/21)
#  => => transferring dockerfile: 218B                                       0.0s
#  => [kali internal] load metadata for docker.io/kalilinux/kali-rolling:la  1.9s
#  => [agents internal] load metadata for docker.io/library/python:3.12-alp  2.0s
#  => [mysql internal] load metadata for docker.io/library/mysql:latest      1.5s
#  => [mysql internal] load .dockerignore                                    0.3s
#  => => transferring context: 2B                                            0.0s
#  => [kali internal] load .dockerignore                                     0.5s
#  => => transferring context: 2B                                            0.0s
#  => [mysql internal] load build context                                    0.4s
#  => => transferring context: 39B                                           0.0s
#  => [mysql 1/2] FROM docker.io/library/mysql:latest@sha256:db32c8ec843c04  0.4s
#  => => resolve docker.io/library/mysql:latest@sha256:db32c8ec843c042a728e  0.3s
#  => [kali 1/3] FROM docker.io/kalilinux/kali-rolling:latest@sha256:60f96e  0.6s
#  => => resolve docker.io/kalilinux/kali-rolling:latest@sha256:60f96e55e47  0.5s
#  => [agents internal] load build context                                   0.0s
#  => [agents 1/4] FROM docker.io/library/python:3.12-alpine@sha256:2d91681  0.5s
#  => => resolve docker.io/library/python:3.12-alpine@sha256:2d91681153dd4b  0.5s
#  => CACHED [mysql 2/2] COPY ./init_database.sql /docker-entrypoint-initdb  0.0s
#  => [mysql] exporting to image                                             0.4s
#  => => exporting layers                                                    0.0s
#  => => exporting manifest sha256:45cee18ff6b5cb671622412b289fbf2f882ea578  0.1s
#  => => exporting config sha256:dfa033d6c9f230948505f360562524ea8214029811  0.1s
# [+] Building 4.0s (13/21)
#  => => transferring dockerfile: 218B                                       0.0s
#  => [kali internal] load metadata for docker.io/kalilinux/kali-rolling:la  1.9s
#  => [agents internal] load metadata for docker.io/library/python:3.12-alp  2.0s
#  => [mysql internal] load metadata for docker.io/library/mysql:latest      1.5s
#  => [mysql internal] load .dockerignore                                    0.3s
#  => => transferring context: 2B                                            0.0s
#  => [kali internal] load .dockerignore                                     0.5s
#  => => transferring context: 2B                                            0.0s
#  => [mysql internal] load build context                                    0.4s
#  => => transferring context: 39B                                           0.0s
#  => [mysql 1/2] FROM docker.io/library/mysql:latest@sha256:db32c8ec843c04  0.4s
#  => => resolve docker.io/library/mysql:latest@sha256:db32c8ec843c042a728e  0.3s
#  => [kali 1/3] FROM docker.io/kalilinux/kali-rolling:latest@sha256:60f96e  0.7s
#  => => resolve docker.io/kalilinux/kali-rolling:latest@sha256:60f96e55e47  0.7s
#  => [agents internal] load build context                                   0.0s
#  => [agents 1/4] FROM docker.io/library/python:3.12-alpine@sha256:2d91681  0.7s
#  => => resolve docker.io/library/python:3.12-alpine@sha256:2d91681153dd4b  0.6s
#  => CACHED [mysql 2/2] COPY ./init_database.sql /docker-entrypoint-initdb  0.0s
#  => [mysql] exporting to image                                             0.6s
#  => => exporting layers                                                    0.0s
#  => => exporting manifest sha256:45cee18ff6b5cb671622412b289fbf2f882ea578  0.1s
#  => => exporting config sha256:dfa033d6c9f230948505f360562524ea8214029811  0.1s
# [+] Building 4.2s (13/21)
#  => => transferring dockerfile: 218B                                       0.0s
#  => [kali internal] load metadata for docker.io/kalilinux/kali-rolling:la  1.9s
#  => [agents internal] load metadata for docker.io/library/python:3.12-alp  2.0s
#  => [mysql internal] load metadata for docker.io/library/mysql:latest      1.5s
#  => [mysql internal] load .dockerignore                                    0.3s
#  => => transferring context: 2B                                            0.0s
#  => [kali internal] load .dockerignore                                     0.5s
#  => => transferring context: 2B                                            0.0s
#  => [mysql internal] load build context                                    0.4s
#  => => transferring context: 39B                                           0.0s
#  => [mysql 1/2] FROM docker.io/library/mysql:latest@sha256:db32c8ec843c04  0.4s
#  => => resolve docker.io/library/mysql:latest@sha256:db32c8ec843c042a728e  0.3s
#  => [kali 1/3] FROM docker.io/kalilinux/kali-rolling:latest@sha256:60f96e  0.9s
#  => => resolve docker.io/kalilinux/kali-rolling:latest@sha256:60f96e55e47  0.8s
#  => [agents internal] load build context                                   0.0s
#  => [agents 1/4] FROM docker.io/library/python:3.12-alpine@sha256:2d91681  0.8s
#  => => resolve docker.io/library/python:3.12-alpine@sha256:2d91681153dd4b  0.8s
#  => CACHED [mysql 2/2] COPY ./init_database.sql /docker-entrypoint-initdb  0.0s
#  => [mysql] exporting to image                                             0.7s
#  => => exporting layers                                                    0.0s
#  => => exporting manifest sha256:45cee18ff6b5cb671622412b289fbf2f882ea578  0.1s
#  => => exporting config sha256:dfa033d6c9f230948505f360562524ea8214029811  0.1s
# [+] Building 4.2s (13/21)
#  => [kali internal] load metadata for docker.io/kalilinux/kali-rolling:la  1.9s
#  => [agents internal] load metadata for docker.io/library/python:3.12-alp  2.0s
#  => [mysql internal] load metadata for docker.io/library/mysql:latest      1.5s
#  => [mysql internal] load .dockerignore                                    0.3s
#  => => transferring context: 2B                                            0.0s
#  => [kali internal] load .dockerignore                                     0.5s
#  => => transferring context: 2B                                            0.0s
#  => [mysql internal] load build context                                    0.4s
#  => => transferring context: 39B                                           0.0s
#  => [mysql 1/2] FROM docker.io/library/mysql:latest@sha256:db32c8ec843c04  0.4s
#  => => resolve docker.io/library/mysql:latest@sha256:db32c8ec843c042a728e  0.3s
#  => [kali 1/3] FROM docker.io/kalilinux/kali-rolling:latest@sha256:60f96e  0.9s
#  => => resolve docker.io/kalilinux/kali-rolling:latest@sha256:60f96e55e47  0.8s
#  => [agents internal] load build context                                   0.0s
#  => [agents 1/4] FROM docker.io/library/python:3.12-alpine@sha256:2d91681  0.8s
#  => => resolve docker.io/library/python:3.12-alpine@sha256:2d91681153dd4b  0.8s
#  => CACHED [mysql 2/2] COPY ./init_database.sql /docker-entrypoint-initdb  0.0s
#  => [mysql] exporting to image                                             0.7s
#  => => exporting layers                                                    0.0s
#  => => exporting manifest sha256:45cee18ff6b5cb671622412b289fbf2f882ea578  0.1s
#  => => exporting config sha256:dfa033d6c9f230948505f360562524ea8214029811  0.1s
#  => => exporting attestation manifest sha256:1c2961c08ac41b45afa4d04eafd9  0.0s
# [+] Building 4.5s (14/21)
#  => [kali internal] load metadata for docker.io/kalilinux/kali-rolling:la  1.9s
#  => [agents internal] load metadata for docker.io/library/python:3.12-alp  2.0s
#  => [mysql internal] load metadata for docker.io/library/mysql:latest      1.5s
#  => [mysql internal] load .dockerignore                                    0.3s
#  => => transferring context: 2B                                            0.0s
#  => [kali internal] load .dockerignore                                     0.5s
#  => => transferring context: 2B                                            0.0s
#  => [mysql internal] load build context                                    0.4s
#  => => transferring context: 39B                                           0.0s
#  => [mysql 1/2] FROM docker.io/library/mysql:latest@sha256:db32c8ec843c04  0.4s
#  => => resolve docker.io/library/mysql:latest@sha256:db32c8ec843c042a728e  0.3s
#  => [kali 1/3] FROM docker.io/kalilinux/kali-rolling:latest@sha256:60f96e  1.0s
#  => => resolve docker.io/kalilinux/kali-rolling:latest@sha256:60f96e55e47  0.9s
#  => [agents internal] load build context                                   0.0s
#  => [agents 1/4] FROM docker.io/library/python:3.12-alpine@sha256:2d91681  1.1s
#  => => resolve docker.io/library/python:3.12-alpine@sha256:2d91681153dd4b  1.0s
#  => CACHED [mysql 2/2] COPY ./init_database.sql /docker-entrypoint-initdb  0.0s
#  => [mysql] exporting to image                                             1.0s
#  => => exporting layers                                                    0.0s
#  => => exporting manifest sha256:45cee18ff6b5cb671622412b289fbf2f882ea578  0.1s
#  => => exporting config sha256:dfa033d6c9f230948505f360562524ea8214029811  0.1s
#  => => exporting attestation manifest sha256:1c2961c08ac41b45afa4d04eafd9  0.2s
# [+] Building 4.5s (16/21)
#  => [mysql internal] load metadata for docker.io/library/mysql:latest      1.5s
#  => [mysql internal] load .dockerignore                                    0.3s
#  => => transferring context: 2B                                            0.0s
#  => [kali internal] load .dockerignore                                     0.5s
#  => => transferring context: 2B                                            0.0s
#  => [mysql internal] load build context                                    0.4s
#  => => transferring context: 39B                                           0.0s
#  => [mysql 1/2] FROM docker.io/library/mysql:latest@sha256:db32c8ec843c04  0.4s
#  => => resolve docker.io/library/mysql:latest@sha256:db32c8ec843c042a728e  0.3s
#  => [kali 1/3] FROM docker.io/kalilinux/kali-rolling:latest@sha256:60f96e  1.0s
#  => => resolve docker.io/kalilinux/kali-rolling:latest@sha256:60f96e55e47  0.9s
#  => [agents internal] load build context                                   0.0s
#  => [agents 1/4] FROM docker.io/library/python:3.12-alpine@sha256:2d91681  1.1s
#  => => resolve docker.io/library/python:3.12-alpine@sha256:2d91681153dd4b  1.1s
#  => CACHED [mysql 2/2] COPY ./init_database.sql /docker-entrypoint-initdb  0.0s
#  => [mysql] exporting to image                                             1.0s
#  => => exporting layers                                                    0.0s
#  => => exporting manifest sha256:45cee18ff6b5cb671622412b289fbf2f882ea578  0.1s
#  => => exporting config sha256:dfa033d6c9f230948505f360562524ea8214029811  0.1s
#  => => exporting attestation manifest sha256:1c2961c08ac41b45afa4d04eafd9  0.3s
#  => CACHED [kali 2/3] RUN apt-get update &&     apt-get install -y --no-i  0.0s
#  => CACHED [kali 3/3] WORKDIR /root                                        0.0s
# [+] Building 4.6s (17/22)
#  => [mysql internal] load .dockerignore                                    0.3s
#  => => transferring context: 2B                                            0.0s
#  => [kali internal] load .dockerignore                                     0.5s
#  => => transferring context: 2B                                            0.0s
#  => [mysql internal] load build context                                    0.4s
#  => => transferring context: 39B                                           0.0s
#  => [mysql 1/2] FROM docker.io/library/mysql:latest@sha256:db32c8ec843c04  0.4s
#  => => resolve docker.io/library/mysql:latest@sha256:db32c8ec843c042a728e  0.3s
#  => [kali 1/3] FROM docker.io/kalilinux/kali-rolling:latest@sha256:60f96e  1.0s
#  => => resolve docker.io/kalilinux/kali-rolling:latest@sha256:60f96e55e47  0.9s
#  => [agents internal] load build context                                   0.0s
#  => [agents 1/4] FROM docker.io/library/python:3.12-alpine@sha256:2d91681  1.1s
#  => => resolve docker.io/library/python:3.12-alpine@sha256:2d91681153dd4b  1.1s
#  => CACHED [mysql 2/2] COPY ./init_database.sql /docker-entrypoint-initdb  0.0s
#  => [mysql] exporting to image                                             1.1s
#  => => exporting layers                                                    0.0s
#  => => exporting manifest sha256:45cee18ff6b5cb671622412b289fbf2f882ea578  0.1s
#  => => exporting config sha256:dfa033d6c9f230948505f360562524ea8214029811  0.1s
#  => => exporting attestation manifest sha256:1c2961c08ac41b45afa4d04eafd9  0.4s
#  => CACHED [kali 2/3] RUN apt-get update &&     apt-get install -y --no-i  0.0s
#  => CACHED [kali 3/3] WORKDIR /root                                        0.0s
#  => [kali] exporting to image                                              0.0s
# [+] Building 4.8s (16/22)
#  => => transferring context: 2B                                            0.0s
#  => [mysql internal] load build context                                    0.4s
#  => => transferring context: 39B                                           0.0s
#  => [mysql 1/2] FROM docker.io/library/mysql:latest@sha256:db32c8ec843c04  0.4s
#  => => resolve docker.io/library/mysql:latest@sha256:db32c8ec843c042a728e  0.3s
#  => [kali 1/3] FROM docker.io/kalilinux/kali-rolling:latest@sha256:60f96e  1.0s
#  => => resolve docker.io/kalilinux/kali-rolling:latest@sha256:60f96e55e47  0.9s
#  => [agents internal] load build context                                   0.1s
#  => [agents 1/4] FROM docker.io/library/python:3.12-alpine@sha256:2d91681  1.1s
#  => => resolve docker.io/library/python:3.12-alpine@sha256:2d91681153dd4b  1.1s
#  => CACHED [mysql 2/2] COPY ./init_database.sql /docker-entrypoint-initdb  0.0s
#  => [mysql] exporting to image                                             1.3s
#  => => exporting layers                                                    0.0s
#  => => exporting manifest sha256:45cee18ff6b5cb671622412b289fbf2f882ea578  0.1s
#  => => exporting config sha256:dfa033d6c9f230948505f360562524ea8214029811  0.1s
#  => => exporting attestation manifest sha256:1c2961c08ac41b45afa4d04eafd9  0.5s
#  => CACHED [kali 2/3] RUN apt-get update &&     apt-get install -y --no-i  0.0s
#  => CACHED [kali 3/3] WORKDIR /root                                        0.0s
#  => [kali] exporting to image                                              0.2s
#  => => exporting layers                                                    0.0s
#  => => exporting manifest sha256:15c2a4153dcc4b1dbda0cc58727b14d2e55896bf  0.1s
#  => => exporting config sha256:e5cd6bff309a491e2b793df39a7af89608fef9011a  0.0s
# [+] Building 4.9s (16/22)
#  => [mysql internal] load build context                                    0.4s
#  => => transferring context: 39B                                           0.0s
#  => [mysql 1/2] FROM docker.io/library/mysql:latest@sha256:db32c8ec843c04  0.4s
#  => => resolve docker.io/library/mysql:latest@sha256:db32c8ec843c042a728e  0.3s
#  => [kali 1/3] FROM docker.io/kalilinux/kali-rolling:latest@sha256:60f96e  1.0s
#  => => resolve docker.io/kalilinux/kali-rolling:latest@sha256:60f96e55e47  0.9s
#  => [agents internal] load build context                                   0.2s
#  => => transferring context: 1.80kB                                        0.0s
#  => [agents 1/4] FROM docker.io/library/python:3.12-alpine@sha256:2d91681  1.1s
#  => => resolve docker.io/library/python:3.12-alpine@sha256:2d91681153dd4b  1.1s
#  => CACHED [mysql 2/2] COPY ./init_database.sql /docker-entrypoint-initdb  0.0s
#  => [mysql] exporting to image                                             1.4s
#  => => exporting layers                                                    0.0s
#  => => exporting manifest sha256:45cee18ff6b5cb671622412b289fbf2f882ea578  0.1s
#  => => exporting config sha256:dfa033d6c9f230948505f360562524ea8214029811  0.1s
#  => => exporting attestation manifest sha256:1c2961c08ac41b45afa4d04eafd9  0.7s
#  => CACHED [kali 2/3] RUN apt-get update &&     apt-get install -y --no-i  0.0s
#  => CACHED [kali 3/3] WORKDIR /root                                        0.0s
#  => [kali] exporting to image                                              0.3s
#  => => exporting layers                                                    0.0s
#  => => exporting manifest sha256:15c2a4153dcc4b1dbda0cc58727b14d2e55896bf  0.1s
#  => => exporting config sha256:e5cd6bff309a491e2b793df39a7af89608fef9011a  0.2s
# [+] Building 5.0s (17/22)
#  => [mysql internal] load build context                                    0.4s
#  => => transferring context: 39B                                           0.0s
#  => [mysql 1/2] FROM docker.io/library/mysql:latest@sha256:db32c8ec843c04  0.4s
#  => => resolve docker.io/library/mysql:latest@sha256:db32c8ec843c042a728e  0.3s
#  => [kali 1/3] FROM docker.io/kalilinux/kali-rolling:latest@sha256:60f96e  1.0s
#  => => resolve docker.io/kalilinux/kali-rolling:latest@sha256:60f96e55e47  0.9s
#  => [agents internal] load build context                                   0.3s
#  => => transferring context: 1.80kB                                        0.0s
#  => [agents 1/4] FROM docker.io/library/python:3.12-alpine@sha256:2d91681  1.1s
#  => => resolve docker.io/library/python:3.12-alpine@sha256:2d91681153dd4b  1.1s
#  => CACHED [mysql 2/2] COPY ./init_database.sql /docker-entrypoint-initdb  0.0s
#  => [mysql] exporting to image                                             1.5s
#  => => exporting layers                                                    0.0s
#  => => exporting manifest sha256:45cee18ff6b5cb671622412b289fbf2f882ea578  0.1s
#  => => exporting config sha256:dfa033d6c9f230948505f360562524ea8214029811  0.1s
#  => => exporting attestation manifest sha256:1c2961c08ac41b45afa4d04eafd9  0.8s
#  => CACHED [kali 2/3] RUN apt-get update &&     apt-get install -y --no-i  0.0s
#  => CACHED [kali 3/3] WORKDIR /root                                        0.0s
#  => [kali] exporting to image                                              0.4s
#  => => exporting layers                                                    0.0s
#  => => exporting manifest sha256:15c2a4153dcc4b1dbda0cc58727b14d2e55896bf  0.1s
#  => => exporting config sha256:e5cd6bff309a491e2b793df39a7af89608fef9011a  0.3s
# [+] Building 5.2s (18/22)
#  => [mysql 1/2] FROM docker.io/library/mysql:latest@sha256:db32c8ec843c04  0.4s
#  => => resolve docker.io/library/mysql:latest@sha256:db32c8ec843c042a728e  0.3s
#  => [kali 1/3] FROM docker.io/kalilinux/kali-rolling:latest@sha256:60f96e  1.0s
#  => => resolve docker.io/kalilinux/kali-rolling:latest@sha256:60f96e55e47  0.9s
#  => [agents internal] load build context                                   0.3s
#  => => transferring context: 1.80kB                                        0.0s
#  => [agents 1/4] FROM docker.io/library/python:3.12-alpine@sha256:2d91681  1.1s
# ...
# pulling 2049f5674b1e: 100% ▕██████████████████▏ 9.0 GB
# pulling 66b9ea09bd5b: 100% ▕██████████████████▏   68 B
# pulling eb4402837c78: 100% ▕██████████████████▏ 1.5 KB
# pulling 832dd9e00a68: 100% ▕██████████████████▏  11 KB
# pulling db59b814cab7: 100% ▕██████████████████▏  488 B
# verifying sha256 digest ⠴ pulling manifest
# pulling 2049f5674b1e: 100% ▕██████████████████▏ 9.0 GB
# pulling 66b9ea09bd5b: 100% ▕██████████████████▏   68 B
# pulling eb4402837c78: 100% ▕██████████████████▏ 1.5 KB
# pulling 832dd9e00a68: 100% ▕██████████████████▏  11 KB
# pulling db59b814cab7: 100% ▕██████████████████▏  488 B
# verifying sha256 digest ⠦ pulling manifest
# pulling 2049f5674b1e: 100% ▕██████████████████▏ 9.0 GB
# pulling 66b9ea09bd5b: 100% ▕██████████████████▏   68 B
# pulling eb4402837c78: 100% ▕██████████████████▏ 1.5 KB
# pulling 832dd9e00a68: 100% ▕██████████████████▏  11 KB
# pulling db59b814cab7: 100% ▕██████████████████▏  488 B
# verifying sha256 digest ⠧ pulling manifest
# pulling 2049f5674b1e: 100% ▕██████████████████▏ 9.0 GB
# pulling 66b9ea09bd5b: 100% ▕██████████████████▏   68 B
# pulling eb4402837c78: 100% ▕██████████████████▏ 1.5 KB
# pulling 832dd9e00a68: 100% ▕██████████████████▏  11 KB
# pulling db59b814cab7: 100% ▕██████████████████▏  488 B
# verifying sha256 digest ⠇ pulling manifest
# pulling 2049f5674b1e: 100% ▕██████████████████▏ 9.0 GB
# pulling 66b9ea09bd5b: 100% ▕██████████████████▏   68 B
# pulling eb4402837c78: 100% ▕██████████████████▏ 1.5 KB
# pulling 832dd9e00a68: 100% ▕██████████████████▏  11 KB
# pulling db59b814cab7: 100% ▕██████████████████▏  488 B
# verifying sha256 digest ⠏ pulling manifest
# pulling 2049f5674b1e: 100% ▕██████████████████▏ 9.0 GB
# pulling 66b9ea09bd5b: 100% ▕██████████████████▏   68 B
# pulling eb4402837c78: 100% ▕██████████████████▏ 1.5 KB
# pulling 832dd9e00a68: 100% ▕██████████████████▏  11 KB
# pulling db59b814cab7: 100% ▕██████████████████▏  488 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 2049f5674b1e: 100% ▕██████████████████▏ 9.0 GB
# pulling 66b9ea09bd5b: 100% ▕██████████████████▏   68 B
# pulling eb4402837c78: 100% ▕██████████████████▏ 1.5 KB
# pulling 832dd9e00a68: 100% ▕██████████████████▏  11 KB
# pulling db59b814cab7: 100% ▕██████████████████▏  488 B
# verifying sha256 digest ⠙ pulling manifest
# pulling 2049f5674b1e: 100% ▕██████████████████▏ 9.0 GB
# pulling 66b9ea09bd5b: 100% ▕██████████████████▏   68 B
# pulling eb4402837c78: 100% ▕██████████████████▏ 1.5 KB
# pulling 832dd9e00a68: 100% ▕██████████████████▏  11 KB
# pulling db59b814cab7: 100% ▕██████████████████▏  488 B
# verifying sha256 digest ⠹ pulling manifest
# pulling 2049f5674b1e: 100% ▕██████████████████▏ 9.0 GB
# pulling 66b9ea09bd5b: 100% ▕██████████████████▏   68 B
# pulling eb4402837c78: 100% ▕██████████████████▏ 1.5 KB
# pulling 832dd9e00a68: 100% ▕██████████████████▏  11 KB
# pulling db59b814cab7: 100% ▕██████████████████▏  488 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 2049f5674b1e: 100% ▕██████████████████▏ 9.0 GB
# pulling 66b9ea09bd5b: 100% ▕██████████████████▏   68 B
# pulling eb4402837c78: 100% ▕██████████████████▏ 1.5 KB
# pulling 832dd9e00a68: 100% ▕██████████████████▏  11 KB
# pulling db59b814cab7: 100% ▕██████████████████▏  488 B
# verifying sha256 digest ⠼ pulling manifest
# pulling 2049f5674b1e: 100% ▕██████████████████▏ 9.0 GB
# pulling 66b9ea09bd5b: 100% ▕██████████████████▏   68 B
# pulling eb4402837c78: 100% ▕██████████████████▏ 1.5 KB
# pulling 832dd9e00a68: 100% ▕██████████████████▏  11 KB
# pulling db59b814cab7: 100% ▕██████████████████▏  488 B
# verifying sha256 digest ⠴ pulling manifest
# pulling 2049f5674b1e: 100% ▕██████████████████▏ 9.0 GB
# pulling 66b9ea09bd5b: 100% ▕██████████████████▏   68 B
# pulling eb4402837c78: 100% ▕██████████████████▏ 1.5 KB
# pulling 832dd9e00a68: 100% ▕██████████████████▏  11 KB
# pulling db59b814cab7: 100% ▕██████████████████▏  488 B
# verifying sha256 digest ⠦ pulling manifest
# pulling 2049f5674b1e: 100% ▕██████████████████▏ 9.0 GB
# pulling 66b9ea09bd5b: 100% ▕██████████████████▏   68 B
# pulling eb4402837c78: 100% ▕██████████████████▏ 1.5 KB
# pulling 832dd9e00a68: 100% ▕██████████████████▏  11 KB
# pulling db59b814cab7: 100% ▕██████████████████▏  488 B
# verifying sha256 digest ⠧ pulling manifest
# pulling 2049f5674b1e: 100% ▕██████████████████▏ 9.0 GB
# pulling 66b9ea09bd5b: 100% ▕██████████████████▏   68 B
# pulling eb4402837c78: 100% ▕██████████████████▏ 1.5 KB
# pulling 832dd9e00a68: 100% ▕██████████████████▏  11 KB
# pulling db59b814cab7: 100% ▕██████████████████▏  488 B
# verifying sha256 digest ⠇ pulling manifest
# pulling 2049f5674b1e: 100% ▕██████████████████▏ 9.0 GB
# pulling 66b9ea09bd5b: 100% ▕██████████████████▏   68 B
# pulling eb4402837c78: 100% ▕██████████████████▏ 1.5 KB
# pulling 832dd9e00a68: 100% ▕██████████████████▏  11 KB
# pulling db59b814cab7: 100% ▕██████████████████▏  488 B
# verifying sha256 digest ⠏ pulling manifest
# pulling 2049f5674b1e: 100% ▕██████████████████▏ 9.0 GB
# pulling 66b9ea09bd5b: 100% ▕██████████████████▏   68 B
# pulling eb4402837c78: 100% ▕██████████████████▏ 1.5 KB
# pulling 832dd9e00a68: 100% ▕██████████████████▏  11 KB
# pulling db59b814cab7: 100% ▕██████████████████▏  488 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 2049f5674b1e: 100% ▕██████████████████▏ 9.0 GB
# pulling 66b9ea09bd5b: 100% ▕██████████████████▏   68 B
# pulling eb4402837c78: 100% ▕██████████████████▏ 1.5 KB
# pulling 832dd9e00a68: 100% ▕██████████████████▏  11 KB
# pulling db59b814cab7: 100% ▕██████████████████▏  488 B
# verifying sha256 digest ⠙ pulling manifest
# pulling 2049f5674b1e: 100% ▕██████████████████▏ 9.0 GB
# pulling 66b9ea09bd5b: 100% ▕██████████████████▏   68 B
# pulling eb4402837c78: 100% ▕██████████████████▏ 1.5 KB
# pulling 832dd9e00a68: 100% ▕██████████████████▏  11 KB
# pulling db59b814cab7: 100% ▕██████████████████▏  488 B
# verifying sha256 digest ⠹ pulling manifest
# pulling 2049f5674b1e: 100% ▕██████████████████▏ 9.0 GB
# pulling 66b9ea09bd5b: 100% ▕██████████████████▏   68 B
# pulling eb4402837c78: 100% ▕██████████████████▏ 1.5 KB
# pulling 832dd9e00a68: 100% ▕██████████████████▏  11 KB
# pulling db59b814cab7: 100% ▕██████████████████▏  488 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 2049f5674b1e: 100% ▕██████████████████▏ 9.0 GB
# pulling 66b9ea09bd5b: 100% ▕██████████████████▏   68 B
# pulling eb4402837c78: 100% ▕██████████████████▏ 1.5 KB
# pulling 832dd9e00a68: 100% ▕██████████████████▏  11 KB
# pulling db59b814cab7: 100% ▕██████████████████▏  488 B
# verifying sha256 digest ⠼ pulling manifest
# pulling 2049f5674b1e: 100% ▕██████████████████▏ 9.0 GB
# pulling 66b9ea09bd5b: 100% ▕██████████████████▏   68 B
# pulling eb4402837c78: 100% ▕██████████████████▏ 1.5 KB
# pulling 832dd9e00a68: 100% ▕██████████████████▏  11 KB
# pulling db59b814cab7: 100% ▕██████████████████▏  488 B
# verifying sha256 digest ⠴ pulling manifest
# pulling 2049f5674b1e: 100% ▕██████████████████▏ 9.0 GB
# pulling 66b9ea09bd5b: 100% ▕██████████████████▏   68 B
# pulling eb4402837c78: 100% ▕██████████████████▏ 1.5 KB
# pulling 832dd9e00a68: 100% ▕██████████████████▏  11 KB
# pulling db59b814cab7: 100% ▕██████████████████▏  488 B
# verifying sha256 digest ⠦ pulling manifest
# pulling 2049f5674b1e: 100% ▕██████████████████▏ 9.0 GB
# pulling 66b9ea09bd5b: 100% ▕██████████████████▏   68 B
# pulling eb4402837c78: 100% ▕██████████████████▏ 1.5 KB
# pulling 832dd9e00a68: 100% ▕██████████████████▏  11 KB
# pulling db59b814cab7: 100% ▕██████████████████▏  488 B
# verifying sha256 digest ⠧ pulling manifest
# pulling 2049f5674b1e: 100% ▕██████████████████▏ 9.0 GB
# pulling 66b9ea09bd5b: 100% ▕██████████████████▏   68 B
# pulling eb4402837c78: 100% ▕██████████████████▏ 1.5 KB
# pulling 832dd9e00a68: 100% ▕██████████████████▏  11 KB
# pulling db59b814cab7: 100% ▕██████████████████▏  488 B
# verifying sha256 digest ⠇ pulling manifest
# pulling 2049f5674b1e: 100% ▕██████████████████▏ 9.0 GB
# pulling 66b9ea09bd5b: 100% ▕██████████████████▏   68 B
# pulling eb4402837c78: 100% ▕██████████████████▏ 1.5 KB
# pulling 832dd9e00a68: 100% ▕██████████████████▏  11 KB
# pulling db59b814cab7: 100% ▕██████████████████▏  488 B
# verifying sha256 digest ⠏ pulling manifest
# pulling 2049f5674b1e: 100% ▕██████████████████▏ 9.0 GB
# pulling 66b9ea09bd5b: 100% ▕██████████████████▏   68 B
# pulling eb4402837c78: 100% ▕██████████████████▏ 1.5 KB
# pulling 832dd9e00a68: 100% ▕██████████████████▏  11 KB
# pulling db59b814cab7: 100% ▕██████████████████▏  488 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 2049f5674b1e: 100% ▕██████████████████▏ 9.0 GB
# pulling 66b9ea09bd5b: 100% ▕██████████████████▏   68 B
# pulling eb4402837c78: 100% ▕██████████████████▏ 1.5 KB
# pulling 832dd9e00a68: 100% ▕██████████████████▏  11 KB
# pulling db59b814cab7: 100% ▕██████████████████▏  488 B
# verifying sha256 digest ⠙ pulling manifest
# pulling 2049f5674b1e: 100% ▕██████████████████▏ 9.0 GB
# pulling 66b9ea09bd5b: 100% ▕██████████████████▏   68 B
# pulling eb4402837c78: 100% ▕██████████████████▏ 1.5 KB
# pulling 832dd9e00a68: 100% ▕██████████████████▏  11 KB
# pulling db59b814cab7: 100% ▕██████████████████▏  488 B
# verifying sha256 digest ⠹ pulling manifest
# pulling 2049f5674b1e: 100% ▕██████████████████▏ 9.0 GB
# pulling 66b9ea09bd5b: 100% ▕██████████████████▏   68 B
# pulling eb4402837c78: 100% ▕██████████████████▏ 1.5 KB
# pulling 832dd9e00a68: 100% ▕██████████████████▏  11 KB
# pulling db59b814cab7: 100% ▕██████████████████▏  488 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 2049f5674b1e: 100% ▕██████████████████▏ 9.0 GB
# pulling 66b9ea09bd5b: 100% ▕██████████████████▏   68 B
# pulling eb4402837c78: 100% ▕██████████████████▏ 1.5 KB
# pulling 832dd9e00a68: 100% ▕██████████████████▏  11 KB
# pulling db59b814cab7: 100% ▕██████████████████▏  488 B
# verifying sha256 digest ⠼ pulling manifest
# pulling 2049f5674b1e: 100% ▕██████████████████▏ 9.0 GB
# pulling 66b9ea09bd5b: 100% ▕██████████████████▏   68 B
# pulling eb4402837c78: 100% ▕██████████████████▏ 1.5 KB
# pulling 832dd9e00a68: 100% ▕██████████████████▏  11 KB
# pulling db59b814cab7: 100% ▕██████████████████▏  488 B
# verifying sha256 digest ⠴ pulling manifest
# pulling 2049f5674b1e: 100% ▕██████████████████▏ 9.0 GB
# pulling 66b9ea09bd5b: 100% ▕██████████████████▏   68 B
# pulling eb4402837c78: 100% ▕██████████████████▏ 1.5 KB
# pulling 832dd9e00a68: 100% ▕██████████████████▏  11 KB
# pulling db59b814cab7: 100% ▕██████████████████▏  488 B
# verifying sha256 digest ⠦ pulling manifest
# pulling 2049f5674b1e: 100% ▕██████████████████▏ 9.0 GB
# pulling 66b9ea09bd5b: 100% ▕██████████████████▏   68 B
# pulling eb4402837c78: 100% ▕██████████████████▏ 1.5 KB
# pulling 832dd9e00a68: 100% ▕██████████████████▏  11 KB
# pulling db59b814cab7: 100% ▕██████████████████▏  488 B
# verifying sha256 digest ⠧ pulling manifest
# pulling 2049f5674b1e: 100% ▕██████████████████▏ 9.0 GB
# pulling 66b9ea09bd5b: 100% ▕██████████████████▏   68 B
# pulling eb4402837c78: 100% ▕██████████████████▏ 1.5 KB
# pulling 832dd9e00a68: 100% ▕██████████████████▏  11 KB
# pulling db59b814cab7: 100% ▕██████████████████▏  488 B
# verifying sha256 digest ⠇ pulling manifest
# pulling 2049f5674b1e: 100% ▕██████████████████▏ 9.0 GB
# pulling 66b9ea09bd5b: 100% ▕██████████████████▏   68 B
# pulling eb4402837c78: 100% ▕██████████████████▏ 1.5 KB
# pulling 832dd9e00a68: 100% ▕██████████████████▏  11 KB
# pulling db59b814cab7: 100% ▕██████████████████▏  488 B
# verifying sha256 digest ⠏ pulling manifest
# pulling 2049f5674b1e: 100% ▕██████████████████▏ 9.0 GB
# pulling 66b9ea09bd5b: 100% ▕██████████████████▏   68 B
# pulling eb4402837c78: 100% ▕██████████████████▏ 1.5 KB
# pulling 832dd9e00a68: 100% ▕██████████████████▏  11 KB
# pulling db59b814cab7: 100% ▕██████████████████▏  488 B
# verifying sha256 digest
# writing manifest
# success

# %% [markdown]
# # List Running Containers
#
# Run this cell to verify all of the containers are up and running.
#
# There should be 6 containers running:
# - mysql
# - webui
# - kali
# - agents
# - ollama
# - tedmed
#
# Once the webui container is active (this usually takes a few seconds longer than the rest of the containers), navigate to `http://localhost:3000` in your browser to access the WebUI.
# Log into WebUI with one of these mock users:
# | email           | password |
# |-------------------|----------|
# | alice@example.com |password |
# | bob@example.com   | password |
# | carol@example.com | password |
# | david@example.com | password |
# | eve@example.com   | password |
# To view the Ted Med Talk blog page, navigate to `http://localhost:8080`.

# %%
# !docker ps
# Out:
# CONTAINER ID   IMAGE                                COMMAND                  CREATED              STATUS                    PORTS                               NAMES
# b626cff8e697   ghcr.io/open-webui/open-webui:main   "bash start.sh"          50 seconds ago       Up 41 seconds (healthy)   0.0.0.0:2010->8080/tcp              webui
# 69ebc5f700f1   agent-image                          "uvicorn app:app --h…"   54 seconds ago       Up 42 seconds             0.0.0.0:2012->8000/tcp              agents
# c188c7ec7301   nginx:stable-alpine                  "/docker-entrypoint.…"   About a minute ago   Up 44 seconds             0.0.0.0:2014->80/tcp                tedmed
# edc8d89980b7   sql-image                            "docker-entrypoint.s…"   About a minute ago   Up 44 seconds             33060/tcp, 0.0.0.0:2013->3306/tcp   mysql
# 0721fd23247c   ollama/ollama:latest                 "/bin/ollama serve"      About a minute ago   Up 44 seconds             0.0.0.0:2011->11434/tcp             ollama
# 33afc7aeea1b   kali-image                           "bash"                   About a minute ago   Up 44 seconds                                                 kali

# %% [markdown]
# ## View AI Container Logs
#
# Run this cell to view the logs of the AI container

# %%
# !docker logs agents -f

# %% [markdown]
# ## Shut Down Containers
#
# Run this cell to stop and remove all running containers

# %%
# !docker compose down
# Out:
# [+] down 0/3
#  ⠋ Container webui  Stopping                                                0.0s
#  ⠋ Container kali   Stopping                                                0.0s
#  ⠋ Container tedmed Stopping                                                0.0s
# [+] down 0/3
#  ⠙ Container webui  Stopping                                                0.2s
#  ⠙ Container kali   Stopping                                                0.2s
#  ⠙ Container tedmed Stopping                                                0.2s
# [+] down 0/3
#  ⠹ Container webui  Stopping                                                0.3s
#  ⠹ Container kali   Stopping                                                0.3s
#  ⠹ Container tedmed Stopping                                                0.3s
# [+] down 0/3
#  ⠸ Container webui  Stopping                                                0.3s
#  ⠸ Container kali   Stopping                                                0.3s
#  ⠸ Container tedmed Stopping                                                0.3s
# [+] down 0/3
#  ⠼ Container webui  Stopping                                                0.4s
#  ⠼ Container kali   Stopping                                                0.4s
#  ⠼ Container tedmed Stopping                                                0.4s
# [+] down 0/3
#  ⠴ Container webui  Stopping                                                0.5s
#  ⠴ Container kali   Stopping                                                0.5s
#  ⠴ Container tedmed Stopping                                                0.5s
# [+] down 0/3
#  ⠦ Container webui  Stopping                                                0.6s
#  ⠦ Container kali   Stopping                                                0.6s
#  ⠦ Container tedmed Stopping                                                0.6s
# [+] down 0/3
#  ⠧ Container webui  Stopping                                                0.7s
#  ⠧ Container kali   Stopping                                                0.7s
#  ⠧ Container tedmed Stopping                                                0.7s
# [+] down 0/3
#  ⠇ Container webui  Stopping                                                0.8s
#  ⠇ Container kali   Stopping                                                0.8s
#  ⠇ Container tedmed Stopping                                                0.8s
# [+] down 0/3
#  ⠏ Container webui  Stopping                                                1.0s
#  ⠏ Container kali   Stopping                                                1.0s
#  ⠏ Container tedmed Stopping                                                1.0s
# [+] down 0/3
#  ⠋ Container webui  Stopping                                                1.0s
#  ⠋ Container kali   Stopping                                                1.0s
#  ⠋ Container tedmed Stopping                                                1.0s
# [+] down 0/3
#  ⠙ Container webui  Stopping                                                1.2s
#  ⠙ Container kali   Stopping                                                1.1s
#  ⠙ Container tedmed Stopping                                                1.1s
# [+] down 0/3
#  ⠹ Container webui  Stopping                                                1.2s
#  ⠹ Container kali   Stopping                                                1.2s
#  ⠹ Container tedmed Removing                                                1.2s
# [+] down 0/3
#  ⠸ Container webui  Stopping                                                1.3s
#  ⠸ Container kali   Stopping                                                1.3s
#  ⠸ Container tedmed Removing                                                1.3s
# [+] down 0/3
#  ⠼ Container webui  Stopping                                                1.4s
#  ⠼ Container kali   Stopping                                                1.4s
#  ⠼ Container tedmed Removing                                                1.4s
# [+] down 0/3
#  ⠴ Container webui  Stopping                                                1.5s
#  ⠴ Container kali   Stopping                                                1.5s
#  ⠴ Container tedmed Removing                                                1.5s
# [+] down 1/3
#  ⠦ Container webui  Stopping                                                1.6s
#  ⠦ Container kali   Stopping                                                1.6s
#  ✔ Container tedmed Removed                                                 1.6s
# [+] down 1/3
#  ⠧ Container webui  Stopping                                                1.7s
#  ⠧ Container kali   Stopping                                                1.7s
#  ✔ Container tedmed Removed                                                 1.6s
# [+] down 1/3
#  ⠇ Container webui  Stopping                                                1.8s
#  ⠇ Container kali   Stopping                                                1.8s
#  ✔ Container tedmed Removed                                                 1.6s
# [+] down 1/3
#  ⠏ Container webui  Stopping                                                1.9s
#  ⠏ Container kali   Stopping                                                1.9s
#  ✔ Container tedmed Removed                                                 1.6s
# [+] down 1/3
#  ⠋ Container webui  Stopping                                                2.0s
#  ⠋ Container kali   Stopping                                                2.0s
#  ✔ Container tedmed Removed                                                 1.6s
# [+] down 1/3
#  ⠙ Container webui  Stopping                                                2.2s
#  ⠙ Container kali   Stopping                                                2.2s
#  ✔ Container tedmed Removed                                                 1.6s
# [+] down 1/3
#  ⠹ Container webui  Stopping                                                2.2s
#  ⠹ Container kali   Stopping                                                2.2s
#  ✔ Container tedmed Removed                                                 1.6s
# [+] down 1/3
#  ⠸ Container webui  Stopping                                                2.3s
#  ⠸ Container kali   Stopping                                                2.3s
#  ✔ Container tedmed Removed                                                 1.6s
# [+] down 1/3
#  ⠼ Container webui  Stopping                                                2.4s
#  ⠼ Container kali   Stopping                                                2.4s
#  ✔ Container tedmed Removed                                                 1.6s
# [+] down 1/3
#  ⠴ Container webui  Stopping                                                2.5s
#  ⠴ Container kali   Stopping                                                2.5s
#  ✔ Container tedmed Removed                                                 1.6s
# [+] down 1/3
#  ⠦ Container webui  Stopping                                                2.6s
#  ⠦ Container kali   Stopping                                                2.6s
#  ✔ Container tedmed Removed                                                 1.6s
# [+] down 1/3
#  ⠧ Container webui  Stopping                                                2.7s
#  ⠧ Container kali   Stopping                                                2.7s
#  ✔ Container tedmed Removed                                                 1.6s
# [+] down 1/3
#  ⠇ Container webui  Stopping                                                2.9s
#  ⠇ Container kali   Stopping                                                2.9s
#  ✔ Container tedmed Removed                                                 1.6s
# [+] down 1/3
#  ⠏ Container webui  Stopping                                                2.9s
#  ⠏ Container kali   Stopping                                                2.9s
#  ✔ Container tedmed Removed                                                 1.6s
# [+] down 1/3
#  ⠋ Container webui  Stopping                                                3.0s
#  ⠋ Container kali   Stopping                                                3.0s
#  ✔ Container tedmed Removed                                                 1.6s
# [+] down 1/3
#  ⠙ Container webui  Stopping                                                3.1s
#  ⠙ Container kali   Stopping                                                3.1s
#  ✔ Container tedmed Removed                                                 1.6s
# [+] down 1/3
#  ⠹ Container webui  Stopping                                                3.3s
#  ⠹ Container kali   Stopping                                                3.3s
#  ✔ Container tedmed Removed                                                 1.6s
# [+] down 1/3
#  ⠸ Container webui  Stopping                                                3.3s
#  ⠸ Container kali   Stopping                                                3.3s
#  ✔ Container tedmed Removed                                                 1.6s
# [+] down 1/3
#  ⠼ Container webui  Removing                                                3.4s
#  ⠼ Container kali   Stopping                                                3.4s
#  ✔ Container tedmed Removed                                                 1.6s
# [+] down 1/3
#  ⠴ Container webui  Removing                                                3.5s
#  ⠴ Container kali   Stopping                                                3.5s
#  ✔ Container tedmed Removed                                                 1.6s
# [+] down 1/3
#  ⠦ Container webui  Removing                                                3.6s
#  ⠦ Container kali   Stopping                                                3.6s
#  ✔ Container tedmed Removed                                                 1.6s
# [+] down 1/3
#  ⠧ Container webui  Removing                                                3.8s
#  ⠧ Container kali   Stopping                                                3.8s
#  ✔ Container tedmed Removed                                                 1.6s
# [+] down 1/3
#  ⠇ Container webui  Removing                                                3.8s
#  ⠇ Container kali   Stopping                                                3.8s
#  ✔ Container tedmed Removed                                                 1.6s
# [+] down 2/5
#  ✔ Container webui  Removed                                                 3.9s
#  ⠏ Container kali   Stopping                                                3.9s
#  ✔ Container tedmed Removed                                                 1.6s
#  ⠋ Container ollama Stopping                                                0.1s
#  ⠋ Container agents Stopping                                                0.1s
# [+] down 2/5
#  ✔ Container webui  Removed                                                 3.9s
#  ⠋ Container kali   Stopping                                                4.0s
#  ✔ Container tedmed Removed                                                 1.6s
#  ⠙ Container ollama Stopping                                                0.2s
#  ⠙ Container agents Stopping                                                0.2s
# [+] down 2/5
#  ✔ Container webui  Removed                                                 3.9s
#  ⠙ Container kali   Stopping                                                4.1s
#  ✔ Container tedmed Removed                                                 1.6s
#  ⠹ Container ollama Stopping                                                0.3s
#  ⠹ Container agents Stopping                                                0.3s
# [+] down 2/5
#  ✔ Container webui  Removed                                                 3.9s
#  ⠹ Container kali   Stopping                                                4.2s
#  ✔ Container tedmed Removed                                                 1.6s
#  ⠸ Container ollama Stopping                                                0.4s
#  ⠸ Container agents Stopping                                                0.4s
# [+] down 2/5
#  ✔ Container webui  Removed                                                 3.9s
#  ⠸ Container kali   Stopping                                                4.3s
#  ✔ Container tedmed Removed                                                 1.6s
#  ⠼ Container ollama Stopping                                                0.5s
#  ⠼ Container agents Stopping                                                0.5s
# [+] down 2/5
#  ✔ Container webui  Removed                                                 3.9s
#  ⠼ Container kali   Stopping                                                4.5s
#  ✔ Container tedmed Removed                                                 1.6s
#  ⠴ Container ollama Stopping                                                0.6s
#  ⠴ Container agents Stopping                                                0.6s
# [+] down 2/5
#  ✔ Container webui  Removed                                                 3.9s
#  ⠴ Container kali   Stopping                                                4.5s
#  ✔ Container tedmed Removed                                                 1.6s
#  ⠦ Container ollama Stopping                                                0.7s
#  ⠦ Container agents Stopping                                                0.7s
# [+] down 2/5
#  ✔ Container webui  Removed                                                 3.9s
#  ⠦ Container kali   Stopping                                                4.6s
#  ✔ Container tedmed Removed                                                 1.6s
#  ⠧ Container ollama Stopping                                                0.8s
#  ⠧ Container agents Stopping                                                0.8s
# [+] down 2/5
#  ✔ Container webui  Removed                                                 3.9s
#  ⠧ Container kali   Stopping                                                4.7s
#  ✔ Container tedmed Removed                                                 1.6s
#  ⠇ Container ollama Stopping                                                0.9s
#  ⠇ Container agents Stopping                                                0.9s
# [+] down 2/5
#  ✔ Container webui  Removed                                                 3.9s
#  ⠇ Container kali   Stopping                                                4.8s
#  ✔ Container tedmed Removed                                                 1.6s
#  ⠏ Container ollama Stopping                                                1.0s
#  ⠏ Container agents Stopping                                                1.0s
# [+] down 2/5
#  ✔ Container webui  Removed                                                 3.9s
#  ⠏ Container kali   Stopping                                                4.9s
#  ✔ Container tedmed Removed                                                 1.6s
#  ⠋ Container ollama Stopping                                                1.1s
#  ⠋ Container agents Stopping                                                1.1s
# [+] down 2/5
#  ✔ Container webui  Removed                                                 3.9s
#  ⠋ Container kali   Stopping                                                5.1s
#  ✔ Container tedmed Removed                                                 1.6s
#  ⠙ Container ollama Stopping                                                1.2s
#  ⠙ Container agents Stopping                                                1.2s
# [+] down 2/5
#  ✔ Container webui  Removed                                                 3.9s
#  ⠙ Container kali   Stopping                                                5.1s
#  ✔ Container tedmed Removed                                                 1.6s
#  ⠹ Container ollama Stopping                                                1.3s
#  ⠹ Container agents Stopping                                                1.3s
# [+] down 2/5
#  ✔ Container webui  Removed                                                 3.9s
#  ⠹ Container kali   Stopping                                                5.3s
#  ✔ Container tedmed Removed                                                 1.6s
#  ⠸ Container ollama Removing                                                1.4s
#  ⠸ Container agents Stopping                                                1.4s
# [+] down 2/5
#  ✔ Container webui  Removed                                                 3.9s
#  ⠸ Container kali   Stopping                                                5.3s
#  ✔ Container tedmed Removed                                                 1.6s
#  ⠼ Container ollama Removing                                                1.5s
#  ⠼ Container agents Stopping                                                1.5s
# [+] down 2/5
#  ✔ Container webui  Removed                                                 3.9s
#  ⠼ Container kali   Stopping                                                5.4s
#  ✔ Container tedmed Removed                                                 1.6s
#  ⠴ Container ollama Removing                                                1.6s
#  ⠴ Container agents Stopping                                                1.6s
# [+] down 2/5
#  ✔ Container webui  Removed                                                 3.9s
#  ⠴ Container kali   Stopping                                                5.5s
#  ✔ Container tedmed Removed                                                 1.6s
#  ⠦ Container ollama Removing                                                1.7s
#  ⠦ Container agents Stopping                                                1.7s
# [+] down 2/5
#  ✔ Container webui  Removed                                                 3.9s
#  ⠦ Container kali   Stopping                                                5.6s
#  ✔ Container tedmed Removed                                                 1.6s
#  ⠧ Container ollama Removing                                                1.8s
#  ⠧ Container agents Stopping                                                1.8s
# [+] down 2/5
#  ✔ Container webui  Removed                                                 3.9s
#  ⠧ Container kali   Stopping                                                5.7s
#  ✔ Container tedmed Removed                                                 1.6s
#  ⠇ Container ollama Removing                                                1.9s
#  ⠇ Container agents Stopping                                                1.9s
# [+] down 2/5
#  ✔ Container webui  Removed                                                 3.9s
#  ⠇ Container kali   Stopping                                                5.8s
#  ✔ Container tedmed Removed                                                 1.6s
#  ⠏ Container ollama Removing                                                2.0s
#  ⠏ Container agents Stopping                                                2.0s
# [+] down 2/5
#  ✔ Container webui  Removed                                                 3.9s
#  ⠏ Container kali   Stopping                                                5.9s
#  ✔ Container tedmed Removed                                                 1.6s
#  ⠋ Container ollama Removing                                                2.1s
#  ⠋ Container agents Stopping                                                2.1s
# [+] down 2/5
#  ✔ Container webui  Removed                                                 3.9s
#  ⠋ Container kali   Stopping                                                6.0s
#  ✔ Container tedmed Removed                                                 1.6s
#  ⠙ Container ollama Removing                                                2.2s
#  ⠙ Container agents Stopping                                                2.2s
# [+] down 3/5
#  ✔ Container webui  Removed                                                 3.9s
#  ⠙ Container kali   Stopping                                                6.1s
#  ✔ Container tedmed Removed                                                 1.6s
#  ✔ Container ollama Removed                                                 2.2s
#  ⠹ Container agents Removing                                                2.3s
# [+] down 3/5
#  ✔ Container webui  Removed                                                 3.9s
#  ⠹ Container kali   Stopping                                                6.3s
#  ✔ Container tedmed Removed                                                 1.6s
#  ✔ Container ollama Removed                                                 2.2s
#  ⠸ Container agents Removing                                                2.4s
# [+] down 3/5
#  ✔ Container webui  Removed                                                 3.9s
#  ⠸ Container kali   Stopping                                                6.3s
#  ✔ Container tedmed Removed                                                 1.6s
#  ✔ Container ollama Removed                                                 2.2s
#  ⠼ Container agents Removing                                                2.5s
# [+] down 3/5
#  ✔ Container webui  Removed                                                 3.9s
#  ⠼ Container kali   Stopping                                                6.4s
#  ✔ Container tedmed Removed                                                 1.6s
#  ✔ Container ollama Removed                                                 2.2s
#  ⠴ Container agents Removing                                                2.6s
# [+] down 4/6
#  ✔ Container webui  Removed                                                 3.9s
#  ⠴ Container kali   Stopping                                                6.6s
#  ✔ Container tedmed Removed                                                 1.6s
#  ✔ Container ollama Removed                                                 2.2s
#  ✔ Container agents Removed                                                 2.6s
#  ⠋ Container mysql  Stopping                                                0.1s
# [+] down 4/6
#  ✔ Container webui  Removed                                                 3.9s
#  ⠦ Container kali   Stopping                                                6.6s
#  ✔ Container tedmed Removed                                                 1.6s
#  ✔ Container ollama Removed                                                 2.2s
#  ✔ Container agents Removed                                                 2.6s
#  ⠙ Container mysql  Stopping                                                0.2s
# [+] down 4/6
#  ✔ Container webui  Removed                                                 3.9s
#  ⠧ Container kali   Stopping                                                6.7s
#  ✔ Container tedmed Removed                                                 1.6s
#  ✔ Container ollama Removed                                                 2.2s
#  ✔ Container agents Removed                                                 2.6s
#  ⠹ Container mysql  Stopping                                                0.3s
# [+] down 4/6
#  ✔ Container webui  Removed                                                 3.9s
#  ⠇ Container kali   Stopping                                                6.9s
#  ✔ Container tedmed Removed                                                 1.6s
#  ✔ Container ollama Removed                                                 2.2s
#  ✔ Container agents Removed                                                 2.6s
#  ⠸ Container mysql  Stopping                                                0.4s
# [+] down 4/6
#  ✔ Container webui  Removed                                                 3.9s
#  ⠏ Container kali   Stopping                                                6.9s
#  ✔ Container tedmed Removed                                                 1.6s
#  ✔ Container ollama Removed                                                 2.2s
#  ✔ Container agents Removed                                                 2.6s
#  ⠼ Container mysql  Stopping                                                0.5s
# [+] down 4/6
#  ✔ Container webui  Removed                                                 3.9s
#  ⠋ Container kali   Stopping                                                7.0s
#  ✔ Container tedmed Removed                                                 1.6s
#  ✔ Container ollama Removed                                                 2.2s
#  ✔ Container agents Removed                                                 2.6s
#  ⠴ Container mysql  Stopping                                                0.6s
# [+] down 4/6
#  ✔ Container webui  Removed                                                 3.9s
#  ⠙ Container kali   Stopping                                                7.2s
#  ✔ Container tedmed Removed                                                 1.6s
#  ✔ Container ollama Removed                                                 2.2s
#  ✔ Container agents Removed                                                 2.6s
#  ⠦ Container mysql  Stopping                                                0.7s
# [+] down 4/6
#  ✔ Container webui  Removed                                                 3.9s
#  ⠹ Container kali   Stopping                                                7.2s
#  ✔ Container tedmed Removed                                                 1.6s
#  ✔ Container ollama Removed                                                 2.2s
#  ✔ Container agents Removed                                                 2.6s
#  ⠧ Container mysql  Stopping                                                0.8s
# [+] down 4/6
#  ✔ Container webui  Removed                                                 3.9s
#  ⠸ Container kali   Stopping                                                7.3s
#  ✔ Container tedmed Removed                                                 1.6s
#  ✔ Container ollama Removed                                                 2.2s
#  ✔ Container agents Removed                                                 2.6s
#  ⠇ Container mysql  Stopping                                                0.9s
# [+] down 4/6
#  ✔ Container webui  Removed                                                 3.9s
#  ⠼ Container kali   Stopping                                                7.5s
#  ✔ Container tedmed Removed                                                 1.6s
#  ✔ Container ollama Removed                                                 2.2s
#  ✔ Container agents Removed                                                 2.6s
#  ⠏ Container mysql  Stopping                                                1.0s
# [+] down 4/6
#  ✔ Container webui  Removed                                                 3.9s
#  ⠴ Container kali   Stopping                                                7.5s
#  ✔ Container tedmed Removed                                                 1.6s
#  ✔ Container ollama Removed                                                 2.2s
#  ✔ Container agents Removed                                                 2.6s
#  ⠋ Container mysql  Stopping                                                1.1s
# [+] down 4/6
#  ✔ Container webui  Removed                                                 3.9s
#  ⠦ Container kali   Stopping                                                7.6s
#  ✔ Container tedmed Removed                                                 1.6s
#  ✔ Container ollama Removed                                                 2.2s
#  ✔ Container agents Removed                                                 2.6s
#  ⠙ Container mysql  Stopping                                                1.2s
# [+] down 4/6
#  ✔ Container webui  Removed                                                 3.9s
#  ⠧ Container kali   Stopping                                                7.8s
#  ✔ Container tedmed Removed                                                 1.6s
#  ✔ Container ollama Removed                                                 2.2s
#  ✔ Container agents Removed                                                 2.6s
#  ⠹ Container mysql  Stopping                                                1.3s
# [+] down 4/6
#  ✔ Container webui  Removed                                                 3.9s
#  ⠇ Container kali   Stopping                                                7.8s
#  ✔ Container tedmed Removed                                                 1.6s
#  ✔ Container ollama Removed                                                 2.2s
#  ✔ Container agents Removed                                                 2.6s
#  ⠸ Container mysql  Stopping                                                1.4s
# [+] down 4/6
#  ✔ Container webui  Removed                                                 3.9s
#  ⠏ Container kali   Stopping                                                7.9s
#  ✔ Container tedmed Removed                                                 1.6s
#  ✔ Container ollama Removed                                                 2.2s
#  ✔ Container agents Removed                                                 2.6s
#  ⠼ Container mysql  Stopping                                                1.5s
# [+] down 4/6
#  ✔ Container webui  Removed                                                 3.9s
#  ⠋ Container kali   Stopping                                                8.1s
#  ✔ Container tedmed Removed                                                 1.6s
#  ✔ Container ollama Removed                                                 2.2s
#  ✔ Container agents Removed                                                 2.6s
#  ⠴ Container mysql  Stopping                                                1.6s
# [+] down 4/6
#  ✔ Container webui  Removed                                                 3.9s
#  ⠙ Container kali   Stopping                                                8.1s
#  ✔ Container tedmed Removed                                                 1.6s
#  ✔ Container ollama Removed                                                 2.2s
#  ✔ Container agents Removed                                                 2.6s
#  ⠦ Container mysql  Stopping                                                1.7s
# [+] down 4/6
#  ✔ Container webui  Removed                                                 3.9s
#  ⠹ Container kali   Stopping                                                8.2s
#  ✔ Container tedmed Removed                                                 1.6s
#  ✔ Container ollama Removed                                                 2.2s
#  ✔ Container agents Removed                                                 2.6s
#  ⠧ Container mysql  Stopping                                                1.8s
# [+] down 4/6
#  ✔ Container webui  Removed                                                 3.9s
#  ⠸ Container kali   Stopping                                                8.4s
#  ✔ Container tedmed Removed                                                 1.6s
#  ✔ Container ollama Removed                                                 2.2s
#  ✔ Container agents Removed                                                 2.6s
#  ⠇ Container mysql  Stopping                                                1.9s
# [+] down 4/6
#  ✔ Container webui  Removed                                                 3.9s
#  ⠼ Container kali   Stopping                                                8.4s
#  ✔ Container tedmed Removed                                                 1.6s
#  ✔ Container ollama Removed                                                 2.2s
#  ✔ Container agents Removed                                                 2.6s
#  ⠏ Container mysql  Stopping                                                2.0s
# [+] down 4/6
#  ✔ Container webui  Removed                                                 3.9s
#  ⠴ Container kali   Stopping                                                8.5s
#  ✔ Container tedmed Removed                                                 1.6s
#  ✔ Container ollama Removed                                                 2.2s
#  ✔ Container agents Removed                                                 2.6s
#  ⠋ Container mysql  Stopping                                                2.1s
# [+] down 4/6
#  ✔ Container webui  Removed                                                 3.9s
#  ⠦ Container kali   Stopping                                                8.7s
#  ✔ Container tedmed Removed                                                 1.6s
#  ✔ Container ollama Removed                                                 2.2s
#  ✔ Container agents Removed                                                 2.6s
#  ⠙ Container mysql  Stopping                                                2.2s
# [+] down 4/6
#  ✔ Container webui  Removed                                                 3.9s
#  ⠧ Container kali   Stopping                                                8.8s
#  ✔ Container tedmed Removed                                                 1.6s
#  ✔ Container ollama Removed                                                 2.2s
#  ✔ Container agents Removed                                                 2.6s
#  ⠹ Container mysql  Removing                                                2.3s
# [+] down 4/6
#  ✔ Container webui  Removed                                                 3.9s
#  ⠇ Container kali   Stopping                                                8.8s
#  ✔ Container tedmed Removed                                                 1.6s
#  ✔ Container ollama Removed                                                 2.2s
#  ✔ Container agents Removed                                                 2.6s
#  ⠸ Container mysql  Removing                                                2.4s
# [+] down 4/6
#  ✔ Container webui  Removed                                                 3.9s
#  ⠏ Container kali   Stopping                                                8.9s
#  ✔ Container tedmed Removed                                                 1.6s
#  ✔ Container ollama Removed                                                 2.2s
#  ✔ Container agents Removed                                                 2.6s
#  ⠼ Container mysql  Removing                                                2.5s
# [+] down 4/6
#  ✔ Container webui  Removed                                                 3.9s
#  ⠋ Container kali   Stopping                                                9.1s
#  ✔ Container tedmed Removed                                                 1.6s
#  ✔ Container ollama Removed                                                 2.2s
#  ✔ Container agents Removed                                                 2.6s
#  ⠴ Container mysql  Removing                                                2.6s
# [+] down 5/6
#  ✔ Container webui  Removed                                                 3.9s
#  ⠙ Container kali   Stopping                                                9.2s
#  ✔ Container tedmed Removed                                                 1.6s
#  ✔ Container ollama Removed                                                 2.2s
#  ✔ Container agents Removed                                                 2.6s
#  ✔ Container mysql  Removed                                                 2.7s
# [+] down 5/6
#  ✔ Container webui  Removed                                                 3.9s
#  ⠹ Container kali   Stopping                                                9.2s
#  ✔ Container tedmed Removed                                                 1.6s
#  ✔ Container ollama Removed                                                 2.2s
#  ✔ Container agents Removed                                                 2.6s
#  ✔ Container mysql  Removed                                                 2.7s
# [+] down 5/6
#  ✔ Container webui  Removed                                                 3.9s
#  ⠸ Container kali   Stopping                                                9.3s
#  ✔ Container tedmed Removed                                                 1.6s
#  ✔ Container ollama Removed                                                 2.2s
#  ✔ Container agents Removed                                                 2.6s
#  ✔ Container mysql  Removed                                                 2.7s
# [+] down 5/6
#  ✔ Container webui  Removed                                                 3.9s
#  ⠼ Container kali   Stopping                                                9.4s
#  ✔ Container tedmed Removed                                                 1.6s
#  ✔ Container ollama Removed                                                 2.2s
#  ✔ Container agents Removed                                                 2.6s
#  ✔ Container mysql  Removed                                                 2.7s
# [+] down 5/6
#  ✔ Container webui  Removed                                                 3.9s
#  ⠴ Container kali   Stopping                                                9.5s
#  ✔ Container tedmed Removed                                                 1.6s
#  ✔ Container ollama Removed                                                 2.2s
#  ✔ Container agents Removed                                                 2.6s
#  ✔ Container mysql  Removed                                                 2.7s
# [+] down 5/6
#  ✔ Container webui  Removed                                                 3.9s
#  ⠦ Container kali   Stopping                                                9.6s
#  ✔ Container tedmed Removed                                                 1.6s
#  ✔ Container ollama Removed                                                 2.2s
#  ✔ Container agents Removed                                                 2.6s
#  ✔ Container mysql  Removed                                                 2.7s
# [+] down 5/6
#  ✔ Container webui  Removed                                                 3.9s
#  ⠧ Container kali   Stopping                                                9.8s
#  ✔ Container tedmed Removed                                                 1.6s
#  ✔ Container ollama Removed                                                 2.2s
#  ✔ Container agents Removed                                                 2.6s
#  ✔ Container mysql  Removed                                                 2.7s
# [+] down 5/6
#  ✔ Container webui  Removed                                                 3.9s
#  ⠇ Container kali   Stopping                                                9.8s
#  ✔ Container tedmed Removed                                                 1.6s
#  ✔ Container ollama Removed                                                 2.2s
#  ✔ Container agents Removed                                                 2.6s
#  ✔ Container mysql  Removed                                                 2.7s
# [+] down 5/6
#  ✔ Container webui  Removed                                                 3.9s
#  ⠏ Container kali   Stopping                                                9.9s
#  ✔ Container tedmed Removed                                                 1.6s
#  ✔ Container ollama Removed                                                 2.2s
#  ✔ Container agents Removed                                                 2.6s
#  ✔ Container mysql  Removed                                                 2.7s
# [+] down 5/6
#  ✔ Container webui  Removed                                                3.9s
#  ⠋ Container kali   Stopping                                               10.0s
#  ✔ Container tedmed Removed                                                1.6s
#  ✔ Container ollama Removed                                                2.2s
#  ✔ Container agents Removed                                                2.6s
#  ✔ Container mysql  Removed                                                2.7s
# [+] down 5/6
#  ✔ Container webui  Removed                                                3.9s
#  ⠙ Container kali   Stopping                                               10.1s
#  ✔ Container tedmed Removed                                                1.6s
#  ✔ Container ollama Removed                                                2.2s
#  ✔ Container agents Removed                                                2.6s
#  ✔ Container mysql  Removed                                                2.7s
# [+] down 5/6
#  ✔ Container webui  Removed                                                3.9s
#  ⠹ Container kali   Stopping                                               10.3s
#  ✔ Container tedmed Removed                                                1.6s
#  ✔ Container ollama Removed                                                2.2s
#  ✔ Container agents Removed                                                2.6s
#  ✔ Container mysql  Removed                                                2.7s
# [+] down 5/6
#  ✔ Container webui  Removed                                                3.9s
#  ⠸ Container kali   Stopping                                               10.3s
#  ✔ Container tedmed Removed                                                1.6s
#  ✔ Container ollama Removed                                                2.2s
#  ✔ Container agents Removed                                                2.6s
#  ✔ Container mysql  Removed                                                2.7s
# [+] down 5/6
#  ✔ Container webui  Removed                                                3.9s
#  ⠼ Container kali   Stopping                                               10.4s
#  ✔ Container tedmed Removed                                                1.6s
#  ✔ Container ollama Removed                                                2.2s
#  ✔ Container agents Removed                                                2.6s
#  ✔ Container mysql  Removed                                                2.7s
# [+] down 5/6
#  ✔ Container webui  Removed                                                3.9s
#  ⠴ Container kali   Stopping                                               10.5s
#  ✔ Container tedmed Removed                                                1.6s
#  ✔ Container ollama Removed                                                2.2s
#  ✔ Container agents Removed                                                2.6s
#  ✔ Container mysql  Removed                                                2.7s
# [+] down 5/6
#  ✔ Container webui  Removed                                                3.9s
#  ⠦ Container kali   Stopping                                               10.6s
#  ✔ Container tedmed Removed                                                1.6s
#  ✔ Container ollama Removed                                                2.2s
#  ✔ Container agents Removed                                                2.6s
#  ✔ Container mysql  Removed                                                2.7s
# [+] down 5/6
#  ✔ Container webui  Removed                                                3.9s
#  ⠧ Container kali   Stopping                                               10.7s
#  ✔ Container tedmed Removed                                                1.6s
#  ✔ Container ollama Removed                                                2.2s
#  ✔ Container agents Removed                                                2.6s
#  ✔ Container mysql  Removed                                                2.7s
# [+] down 5/6
#  ✔ Container webui  Removed                                                3.9s
#  ⠇ Container kali   Stopping                                               10.8s
#  ✔ Container tedmed Removed                                                1.6s
#  ✔ Container ollama Removed                                                2.2s
#  ✔ Container agents Removed                                                2.6s
#  ✔ Container mysql  Removed                                                2.7s
# [+] down 5/6
#  ✔ Container webui  Removed                                                3.9s
#  ⠏ Container kali   Removing                                               11.0s
#  ✔ Container tedmed Removed                                                1.6s
#  ✔ Container ollama Removed                                                2.2s
#  ✔ Container agents Removed                                                2.6s
#  ✔ Container mysql  Removed                                                2.7s
# [+] down 5/6
#  ✔ Container webui  Removed                                                3.9s
#  ⠋ Container kali   Removing                                               11.1s
#  ✔ Container tedmed Removed                                                1.6s
#  ✔ Container ollama Removed                                                2.2s
#  ✔ Container agents Removed                                                2.6s
#  ✔ Container mysql  Removed                                                2.7s
# [+] down 5/6
#  ✔ Container webui  Removed                                                3.9s
#  ⠙ Container kali   Removing                                               11.1s
#  ✔ Container tedmed Removed                                                1.6s
#  ✔ Container ollama Removed                                                2.2s
#  ✔ Container agents Removed                                                2.6s
#  ✔ Container mysql  Removed                                                2.7s
# [+] down 5/6
#  ✔ Container webui  Removed                                                3.9s
#  ⠹ Container kali   Removing                                               11.2s
#  ✔ Container tedmed Removed                                                1.6s
#  ✔ Container ollama Removed                                                2.2s
#  ✔ Container agents Removed                                                2.6s
#  ✔ Container mysql  Removed                                                2.7s
# [+] down 6/7
#  ✔ Container webui            Removed                                      3.9s
#  ✔ Container kali             Removed                                      11.3s
#  ✔ Container tedmed           Removed                                      1.6s
#  ✔ Container ollama           Removed                                      2.2s
#  ✔ Container agents           Removed                                      2.6s
#  ✔ Container mysql            Removed                                      2.7s
#  ⠋ Network ci-attacks_billnet Removing                                     0.0s
# [+] down 6/7
#  ✔ Container webui            Removed                                      3.9s
#  ✔ Container kali             Removed                                      11.3s
#  ✔ Container tedmed           Removed                                      1.6s
#  ✔ Container ollama           Removed                                      2.2s
#  ✔ Container agents           Removed                                      2.6s
#  ✔ Container mysql            Removed                                      2.7s
#  ⠙ Network ci-attacks_billnet Removing                                     0.1s
# [+] down 6/7
#  ✔ Container webui            Removed                                      3.9s
#  ✔ Container kali             Removed                                      11.3s
#  ✔ Container tedmed           Removed                                      1.6s
#  ✔ Container ollama           Removed                                      2.2s
#  ✔ Container agents           Removed                                      2.6s
#  ✔ Container mysql            Removed                                      2.7s
#  ⠹ Network ci-attacks_billnet Removing                                     0.2s
# [+] down 7/7
#  ✔ Container webui            Removed                                      3.9s
#  ✔ Container kali             Removed                                      11.3s
#  ✔ Container tedmed           Removed                                      1.6s
#  ✔ Container ollama           Removed                                      2.2s
#  ✔ Container agents           Removed                                      2.6s
#  ✔ Container mysql            Removed                                      2.7s
#  ✔ Network ci-attacks_billnet Removed                                      0.2s
